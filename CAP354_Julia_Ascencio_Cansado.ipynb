# %% [markdown]
# ## Identifying Aggregations of Waste
# ### Atividade Final CAP-354 Inteligência Artificial
# Prof. Dr. Elcio Hideiti Shiguemori and Prof. Dr. Lamartine Nogueira Frutuoso Guimarães
# <br>
# Júlia Ascencio Cansado - 511871/2025
#
# Notebook focused on the label model for combining different source / method data creation

# %%
# !pip install earthengine-api
# !pip install folium
# !pip install pandas
# !pip install tensorflow 

import ee
import pandas as pd
import numpy as np
import folium
from folium.utilities import image_to_url
import os
import zipfile
import rasterio
from rasterio.windows import Window

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import MeanIoU
# Out:
# 2025-06-13 14:34:11.353853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749825251.366009  584651 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749825251.369693  584651 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749825251.380658  584651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749825251.380671  584651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749825251.380672  584651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749825251.380674  584651 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-13 14:34:11.384085: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Previous steps
#
# Before running this notebook, I ran a [Google Earth Engine script](https://code.earthengine.google.com/8df4a25d5db8b07ffeee622498212e62) to create weak supervision samples - both supervised (using Random Forest) and unsupervised (using Kmeans).
# <br>
# The results of that script are used below, accessed through earthengine-api.

# %%
# Authenticate and initialize Earth Engine
try:
    ee.Initialize(project='dumpsites-id')
except ee.EEException as e:
    ee.Authenticate()
    ee.Initialize(project='dumpsites-id')

# %%
# Parameters
PATCH_SIZE = 128  
SCALE = 10  
STRIDE = 64 
BANDS = ['B2', 'B3', 'B4', 'B8', 'B11', 'B12', 'NDVI', 'NDWI', 'NDBI', 'WasteIndex']
# SUPERVISED = ['final_supervised_label']
SUPERVISED = ['kmeans_validated_label']  
PATCHES_PER_GEOM = 100  
MAX_TRIES = 3            
KERNEL_SIZE  = 128
BATCH_SIZE = 16 
BUFFER_SIZE = 100 
EPOCHS = 20 
NUM_BANDS = len(BANDS)

MOSAIC_VERSION = '4'
SAMPLE_VERSION = '5'

# Define training polygons - this is also in the Earth Engine script
trainingPolys = ee.FeatureCollection('projects/dumpsites-id/assets/export_geoms_train_v1')
validationPolys = ee.FeatureCollection('projects/dumpsites-id/assets/export_geoms_val_v1')
testingPolys = ee.FeatureCollection('projects/dumpsites-id/assets/export_geoms_test_v1')


composite = ee.Image('projects/dumpsites-id/assets/pws_waste_detection_label_v6').select(BANDS)
labels = ee.Image('projects/dumpsites-id/assets/pws_waste_detection_label_v6').select(SUPERVISED)

labeled_image = composite.addBands(labels)

geometries_train = trainingPolys.geometry().getInfo()
geometries_val = validationPolys.geometry().getInfo()
geometries_test = testingPolys.geometry().getInfo()

# %% [markdown]
# ### Preparing geometries for exporting training patches
# The outputs of the previously mentioned Google Earth Engine script are ee.FeatureCollections, which we need to transform into a list of ee.Geometry(ies) to iterate over (extracting patches from each one).
# Remember that after extraction you'll have to upload them into your environment for training/validation

# %%
def multipoly2polylist(multipoly):
    size = len(multipoly.get('coordinates'))
    print(size)
    polylist = ee.List.sequence(0, ee.Number(size).subtract(1))
    newList = []
    # print(polylist.getInfo())
    for i in polylist.getInfo():
        coords = ee.Geometry.Polygon(multipoly.get('coordinates')[i])
        newList.append(coords)
    return newList
    
separate_geoms_train = multipoly2polylist(geometries_train)
separate_geoms_val = multipoly2polylist(geometries_val)
separate_geoms_test = multipoly2polylist(geometries_test)
# Out:
# 5
# 1
# 1

# %%
# Test geometries
print(separate_geoms_val)
# Out:
# [ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "GeometryConstructors.Polygon",
#     "arguments": {
#       "coordinates": {
#         "constantValue": [
#           [
#             [
#               -46.5893031492091,
#               -23.450167167105985
#             ],
#             [
#               -46.54559952190209,
#               -23.450167162383654
#             ],
#             [
#               -46.5018958573013,
#               -23.450167212934264
#             ],
#             [
#               -46.5018958573013,
#               -23.384065497627702
#             ],
#             [
#               -46.54559952190209,
#               -23.384065512205307
#             ],
#             [
#               -46.5893031492091,
#               -23.384065498353895
#             ],
#             [
#               -46.5893031492091,
#               -23.450167167105985
#             ]
#           ]
#         ]
#       },
#       "evenOdd": {
#         "constantValue": true
#       }
#     }
#   }
# })]

# %%
# Join Sentinel imagery and label
featureStack = ee.Image.cat([
  composite.select(BANDS).unmask(0),
  labels.select(SUPERVISED).unmask(0)
]).float()

list = ee.List.repeat(1, KERNEL_SIZE)
lists = ee.List.repeat(list, KERNEL_SIZE)
kernel = ee.Kernel.fixed(KERNEL_SIZE, KERNEL_SIZE, lists)

arrays = featureStack.neighborhoodToArray(kernel)

# %%
# Visualize training data
label_vis_params = {
    'min': 0,
    'max': 1,
    'palette': ['black', 'red'] 
}

map_center = ee.Geometry.MultiPolygon(separate_geoms_train).centroid().coordinates().getInfo()[::-1] 
zoom_level = 11 

m = folium.Map(location=map_center, zoom_start=zoom_level)

tile_url = labels.select(SUPERVISED).getMapId(label_vis_params)['tile_fetcher'].url_format
folium.TileLayer(
    tiles=tile_url,
    attr='Earth Engine Labels',
    overlay=True,
    name='Supervised Labels'
).add_to(m)

folium.GeoJson(
    trainingPolys.getInfo(),
    name='Training Geometries',
    style_function=lambda x: {
        'fillColor': 'blue', 
        'color': 'blue',          #
        'weight': 2,
        'fillOpacity': 0.6
    }
).add_to(m)

folium.GeoJson(
    validationPolys.getInfo(),
    name='Validation Geometries',
    style_function=lambda x: {
        'fillColor': 'green', 
        'color': 'green',          #
        'weight': 2,
        'fillOpacity': 0.6
    }
).add_to(m)

folium.GeoJson(
    testingPolys.getInfo(),
    name='Testing Geometries',
    style_function=lambda x: {
        'fillColor': 'red', 
        'color': 'red',          #
        'weight': 2,
        'fillOpacity': 0.6
    }
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab80dc12aef45f936cc76ea3c6f3aa47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab80dc12aef45f936cc76ea3c6f3aa47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab80dc12aef45f936cc76ea3c6f3aa47 = L.map(
#                 &quot;map_ab80dc12aef45f936cc76ea3c6f3aa47&quot;,
#                 {
#                     center: [-23.45590209584878, -46.79973625917231],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05c2b7a22475c816c4fb3d40022db70e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05c2b7a22475c816c4fb3d40022db70e.addTo(map_ab80dc12aef45f936cc76ea3c6f3aa47);
#
#
#             var tile_layer_0410bc0631605a9fc8cae28b027ee80d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/dumpsites-id/maps/447dc17a17bffe957c3387dd62664b80-3b69219872a67676e149007955aecd7a/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Earth Engine Labels&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0410bc0631605a9fc8cae28b027ee80d.addTo(map_ab80dc12aef45f936cc76ea3c6f3aa47);
#
#
#         function geo_json_8cb531f70a2137fe86e3d51fc3bf2daf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_8cb531f70a2137fe86e3d51fc3bf2daf_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8cb531f70a2137fe86e3d51fc3bf2daf = L.geoJson(null, {
#                 onEachFeature: geo_json_8cb531f70a2137fe86e3d51fc3bf2daf_onEachFeature,
#
#                 style: geo_json_8cb531f70a2137fe86e3d51fc3bf2daf_styler,
#             ...{
# }
#         });
#
#         function geo_json_8cb531f70a2137fe86e3d51fc3bf2daf_add (data) {
#             geo_json_8cb531f70a2137fe86e3d51fc3bf2daf
#                 .addData(data);
#         }
#             geo_json_8cb531f70a2137fe86e3d51fc3bf2daf_add({&quot;columns&quot;: {&quot;system:index&quot;: &quot;String&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-47.004017371610175, -23.428134786104497], [-46.96473497378583, -23.42813474868388], [-46.925452515622204, -23.428134778997094], [-46.925452515622204, -23.369626927003683], [-46.96473497378583, -23.36962694634506], [-47.00401737161018, -23.36962693083241], [-47.004017371610175, -23.428134786104497]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;00000000000000000000&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-46.93248005864101, -23.49099027270568], [-46.86656112736339, -23.490990247592155], [-46.86656112736339, -23.435563613974132], [-46.932480058641005, -23.435563630715208], [-46.93248005864101, -23.49099027270568]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;00000000000000000001&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-46.83703300753887, -23.507992827195746], [-46.79102840721667, -23.50799281980958], [-46.74502386373946, -23.50799280871495], [-46.74502386373946, -23.444383714821914], [-46.79102840721668, -23.444383732992502], [-46.83703300753887, -23.444383739558003], [-46.83703300753887, -23.507992827195746]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;00000000000000000002&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-46.81780978960086, -23.372547594458087], [-46.77660990856571, -23.372547606324787], [-46.73541006095229, -23.372547633841336], [-46.7354100609523, -23.30634777756902], [-46.77660990856572, -23.306347811576913], [-46.81780978960086, -23.30634776991179], [-46.81780978960086, -23.372547594458087]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;00000000000000000003&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-46.50911516921199, -23.73467123428834], [-46.45143664252258, -23.7

# %%
n = 20 
N = 200 

# Export one type oof data at a time
polyList = trainingPolys
# polyList = validationPolys
polyList = testingPolys 

if polyList == trainingPolys:        # original ee.FeatureCollection
    base = 'training_patches'       # name base
    geoms = separate_geoms_train     # list of ee.Geometries
elif polyList == validationPolys:
    base = 'validation_patches'
    geoms = separate_geoms_val
elif polyList == testingPolys:
    base = 'testing_patches'
    geoms = separate_geoms_test
else:
    print('something is wrong')

# print(base)
# print(geoms)

BASE  = base+'_'+SUPERVISED[0]+'_'+MOSAIC_VERSION+'_v'+SAMPLE_VERSION
GDRIVE = 'dumpsites_id'
FOLDER = f'{base}_v{SAMPLE_VERSION}'

SIZE = len(geoms)*N
print(f'{base}: {(SIZE)}')

# Export all the training data 
for g in range(polyList.size().getInfo()):
  geomSample = ee.FeatureCollection([])
  for i in range(n):
    sample = arrays.sample(
      region = ee.Feature(sep_geoms[g]).geometry(), 
      scale = 10, 
      numPixels = N / n, # Size of the shard.
      seed = i,
      tileScale = 8
    )
    geomSample = geomSample.merge(sample)
  
  desc = BASE+ '_g' + str(g)

  task = ee.batch.Export.table.toDrive(
   collection = geomSample,
   description = desc, 
   folder = GDRIVE+'/'+FOLDER, 
   fileNamePrefix = desc,
   fileFormat = 'TFRecord',
   selectors = BANDS + [SUPERVISED]
  )
  # task.start() --> uncomment to start exporting tasks in EE
# Out:
# testing_patches: 200

# %% [markdown]
# ## Getting and preparing input data
# Before training, I have to get and prepare the exported samples (here they can be the one generated with Random Forest or KMeans)

# %%
def parse_tfrecord_function(example_proto):
    feature_description = {
        band: tf.io.FixedLenFeature(shape=[PATCH_SIZE, PATCH_SIZE], dtype=tf.float32) 
        for band in BANDS
    }
    feature_description[SUPERVISED[0]] = tf.io.FixedLenFeature(
        shape=[PATCH_SIZE, PATCH_SIZE], dtype=tf.float32 # Or tf.int32 if labels are integer
    )

    parsed_features = tf.io.parse_single_example(example_proto, feature_description)

    image_bands = [parsed_features[band] for band in BANDS]
    image = tf.stack(image_bands, axis=-1)
    

    label = tf.expand_dims(parsed_features[SUPERVISED[0]], axis=-1)

    # Normalize image 
    image = image / 10000.0 

    return image, label

def create_dataset(tfrecord_paths, batch_size, buffer_size, shuffle=True):
    dataset = tf.data.TFRecordDataset(tfrecord_paths)
    if shuffle:
        dataset = dataset.shuffle(buffer_size)
    dataset = dataset.map(parse_tfrecord_function, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size) # Or tf.data.AUTOTUNE
    return dataset

# %%
# WHICH LABEL AM I USING NOW?
print(SUPERVISED[0])
# Out:
# kmeans_validated_label

# %%
import os
print(os.getcwd())
print(base) #chaeck base
# Out:
# /mnt/nfs/assets/dumpsites/notebooks
# testing_patches

# %%
tfrecord_dir = '/mnt/nfs/assets/dumpsites/data/' + SUPERVISED[0] + '_v' + SAMPLE_VERSION

tfrecord_files = [os.path.join(tfrecord_dir, f) for f in os.listdir(tfrecord_dir) if f.endswith('.tfrecord.gz')]
# print(tfrecord_files)

print(f"Found {len(tfrecord_files)} TFRecord files.")
print(f"Example file: {tfrecord_files[0]}")

# # Create the training dataset
train_dataset = create_dataset(tfrecord_files, BATCH_SIZE, BUFFER_SIZE)
print(train_dataset)
# Out:
# Found 6 TFRecord files.
# Example file: /mnt/nfs/assets/dumpsites/data/kmeans_validated_label_v5/training_patches_kmeans_validated_label_1_v5_g4.tfrecord.gz
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None))>

# %%
def parse_tfrecord_example(example_proto):
    """
    Parses a single tf.train.Example proto using the predefined FEATURES_DICT.
    Args:
        example_proto: A serialized Example.
    Returns:
        A dictionary of tensors, keyed by feature name.
    """
    return tf.io.parse_single_example(example_proto, FEATURES_DICT)

def stack_and_split(parsed_features):

    tensors_list = [parsed_features.get(key) for key in FEATURES_ORDER]
    
    stacked_chw = tf.stack(tensors_list, axis=0)
    
    stacked_hwc = tf.transpose(stacked_chw, [1, 2, 0])

    image = stacked_hwc[:, :, :NUM_BANDS]
    label = stacked_hwc[:, :, NUM_BANDS:] # This will be [PATCH_SIZE, PATCH_SIZE, NUM_CLASSES]


    image = image / 10000.0


    return image, label

def get_dataset(pattern, compression_type='GZIP'):

    glob_paths = tf.io.gfile.glob(pattern)
    if not glob_paths:
        raise FileNotFoundError(f"No files found matching pattern: {pattern}")
    
    dataset = tf.data.Dataset.from_tensor_slices(glob_paths)
    
    dataset = dataset.shuffle(len(glob_paths))

    dataset = dataset.interleave(
        lambda filepath: tf.data.TFRecordDataset(filepath, compression_type=compression_type),
        cycle_length=tf.data.AUTOTUNE, # Read from multiple files concurrently
        num_parallel_calls=tf.data.AUTOTUNE
    )

    dataset = dataset.map(parse_tfrecord_example, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.map(stack_and_split, num_parallel_calls=tf.data.AUTOTUNE)
    
    return dataset

def get_base_dataset(base_type='training_patches'):
 
    glob_pattern = tfrecord_dir + '/' + base_type + '*tfrecord.gz'

    dataset = get_dataset(glob_pattern, compression_type='GZIP') # Ensure GZIP if your files are .gz

    dataset = dataset.shuffle(BUFFER_SIZE, reshuffle_each_iteration=True)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.repeat() # Repeat indefinitely for training loop
    dataset = dataset.prefetch(tf.data.AUTOTUNE) # Prefetch for performance
    return dataset

def get_preview_dataset(num_batches=3, base_type='training_patches'):
    glob_pattern = tfrecord_dir + '/' + base_type + '*tfrecord.gz'
    dataset = get_dataset(glob_pattern, compression_type='GZIP')
    dataset = dataset.shuffle(BUFFER_SIZE) # Shuffle for diverse samples
    dataset = dataset.batch(1) # Process one image at a time for visualization
    return dataset.take(num_batches) # Take only a few batches for preview

# %%
FEATURES_DICT = {
    band: tf.io.FixedLenFeature(shape=[PATCH_SIZE, PATCH_SIZE], dtype=tf.float32)
    for band in BANDS
}
FEATURES_DICT[SUPERVISED[0]] = tf.io.FixedLenFeature(
    shape=[PATCH_SIZE, PATCH_SIZE], dtype=tf.float32 # Use tf.int32 if your labels are strictly integers and not floats
)

FEATURES_ORDER = BANDS + [SUPERVISED[0]]

print(f"Looking for TFRecord files in: {tfrecord_dir}")
training_dataset = get_base_dataset()
validation_dataset = get_base_dataset(base_type='validation_patches')

print("\nVerifying training dataset structure...")
try:
    for image_batch, label_batch in training_dataset.take(1):
        print(f"Batch Image Shape: {image_batch.shape}")    # Expected: (BATCH_SIZE, PATCH_SIZE, PATCH_SIZE, NUM_BANDS)
        print(f"Batch Label Shape: {label_batch.shape}")    # Expected: (BATCH_SIZE, PATCH_SIZE, PATCH_SIZE, NUM_CLASSES)
        print(f"Image Dtype: {image_batch.dtype}")
        print(f"Label Dtype: {label_batch.dtype}")
        print("Dataset structure verified successfully.")
except Exception as e:
    print(f"Error verifying dataset structure: {e}")
    print("Please check your TFRecord files and parsing logic.")
    exit()


print("\nVerifying validation dataset structure...")
try:
    for image_batch, label_batch in validation_dataset.take(1):
        print(f"Batch Image Shape: {image_batch.shape}")    # Expected: (BATCH_SIZE, PATCH_SIZE, PATCH_SIZE, NUM_BANDS)
        print(f"Batch Label Shape: {label_batch.shape}")    # Expected: (BATCH_SIZE, PATCH_SIZE, PATCH_SIZE, NUM_CLASSES)
        print(f"Image Dtype: {image_batch.dtype}")
        print(f"Label Dtype: {label_batch.dtype}")
        print("Dataset structure verified successfully.")
except Exception as e:
    print(f"Error verifying dataset structure: {e}")
    print("Please check your TFRecord files and parsing logic.")
    exit()
# Out:
# Looking for TFRecord files in: /mnt/nfs/assets/dumpsites/data/kmeans_validated_label_v5
#
# Verifying training dataset structure...
# Batch Image Shape: (16, 128, 128, 10)
# Batch Label Shape: (16, 128, 128, 1)
# Image Dtype: <dtype: 'float32'>
# Label Dtype: <dtype: 'float32'>
# Dataset structure verified successfully.
#
# Verifying validation dataset structure...
# Batch Image Shape: (16, 128, 128, 10)
# Batch Label Shape: (16, 128, 128, 1)
# Image Dtype: <dtype: 'float32'>
# Label Dtype: <dtype: 'float32'>
# Dataset structure verified successfully.

# %% [markdown]
# ### Defining model and training
# Here I am using a U-Net based architecture

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def unet_model(input_shape, num_classes, num_bands):
    inputs = layers.Input(input_shape)

    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = layers.Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = layers.Conv2D(512, 3, activation='relu', padding='same')(conv4)
    drop4 = layers.Dropout(0.5)(conv4)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = layers.Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = layers.Conv2D(1024, 3, activation='relu', padding='same')(conv5)
    drop5 = layers.Dropout(0.5)(conv5)

    up6 = layers.Conv2DTranspose(512, 2, strides=(2, 2), padding='same')(drop5)
    up6 = layers.concatenate([up6, drop4])
    conv6 = layers.Conv2D(512, 3, activation='relu', padding='same')(up6)
    conv6 = layers.Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = layers.Conv2DTranspose(256, 2, strides=(2, 2), padding='same')(conv6)
    up7 = layers.concatenate([up7, conv3])
    conv7 = layers.Conv2D(256, 3, activation='relu', padding='same')(up7)
    conv7 = layers.Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(conv7)
    up8 = layers.concatenate([up8, conv2])
    conv8 = layers.Conv2D(128, 3, activation='relu', padding='same')(up8)
    conv8 = layers.Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(conv8)
    up9 = layers.concatenate([up9, conv1])
    conv9 = layers.Conv2D(64, 3, activation='relu', padding='same')(up9)
    conv9 = layers.Conv2D(64, 3, activation='relu', padding='same')(conv9)


    outputs = layers.Conv2D(num_classes, 1, activation='sigmoid')(conv9)
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# %%
NUM_CLASSES = 1
input_shape = (PATCH_SIZE, PATCH_SIZE, NUM_BANDS)
model = unet_model(input_shape, NUM_CLASSES, NUM_BANDS)

# Choose loss function and metrics
# For binary segmentation, BinaryCrossentropy is common.
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=False)

metrics = [
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.MeanIoU(num_classes=2, name='mean_iou') # For binary classification (0 or 1)
]

model.compile(optimizer='adam', loss=loss_fn, metrics=metrics)

# summary
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 10)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │      5,824 │ input_layer_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_57[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 64, 64,    │          0 │ conv2d_58[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_12… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_59[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 32, 32,    │          0 │ conv2d_60[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_13… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_61[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 16, 16,    │          0 │ conv2d_62[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_14… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ conv2d_63[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_64[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_15    │ (None, 8, 8, 512) │          0 │ dropout_6[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_15… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (None, 8, 8,      │  9,438,208 │ conv2d_65[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 8, 8,      │          0 │ conv2d_66[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_12 │ (None, 16, 16,    │  2,097,664 │ dropout_7[0][0]   │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_67 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate_12[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_68 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ conv2d_67[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 32, 32,    │    524,544 │ conv2d_68[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_62[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_13[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_69[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 64, 64,    │    131,200 │ conv2d_70[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_60[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_14[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_71[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 128, 128,  │     32,832 │ conv2d_72[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_58[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_15[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_73[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_74[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,035,777 (118.39 MB)
#  Trainable params: 31,035,777 (118.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Function for looking at the input, label and prediction of the model
import matplotlib.pyplot as plt

class ImagePredictionCallback(tf.keras.callbacks.Callback):
    def __init__(self, preview_dataset, frequency=5, rgb_band_indices=[2, 1, 0]):
        super().__init__()
        self.preview_dataset = preview_dataset
        self.frequency = frequency
        self.rgb_band_indices = rgb_band_indices

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.frequency == 0: # +1 because epoch is 0-indexed
            print(f"\n--- Previewing predictions at Epoch {epoch + 1} ---")
            counter = 0
            for i, (pure_image, supervised_label) in enumerate(self.preview_dataset):
                if counter >= 3: # Limit to 3 previews per epoch
                    break
                test_pred_raw = self.model.predict(pure_image) # Use self.model
                
                # Plotting
                fig, axes = plt.subplots(1, 3, figsize=(15, 5)) # Adjusted figsize for better viewing

                rgb_display = tf.gather(pure_image[0], tf.constant(self.rgb_band_indices), axis=-1)
                rgb_display = tf.clip_by_value(rgb_display, 0.0, 1.0) * 255
                axes[0].imshow(rgb_display.numpy().astype(np.uint8))

                band_names = [BANDS[idx] for idx in self.rgb_band_indices]
                axes[0].set_title('Original Image (B8,B4,B3)')
                axes[0].axis('off')

                axes[1].imshow(supervised_label[0, :, :, 0].numpy(), cmap="gray", vmin=0, vmax=1)
                axes[1].set_title('Ground Truth Label')
                axes[1].axis('off')

                predicted_mask = (test_pred_raw[0, :, :, 0] > 0.5).astype(np.float32) # Threshold at 0.5 for binary
                axes[2].imshow(predicted_mask, cmap="gray", vmin=0, vmax=1)
                axes[2].set_title(f'Model Prediction (Epoch {epoch + 1})')
                axes[2].axis('off')

                plt.tight_layout()
                plt.show()
                counter += 1

# %%
def get_counting_dataset(base_type='training_patches'):
    glob_pattern = tfrecord_dir + '/' + base_type + '*tfrecord.gz'
    dataset = get_dataset(glob_pattern, compression_type='GZIP')
    # No batching, no repeating, no shuffling for counting
    return dataset

# %%
print("\nCounting total records in the training dataset...")
counting_dataset = get_counting_dataset()
TRAIN_SIZE = 0
for _ in counting_dataset:
    TRAIN_SIZE += 1
print(f"Total training records (TRAIN_SIZE): {TRAIN_SIZE}")

if TRAIN_SIZE == 0:
    raise ValueError("TRAIN_SIZE is 0. No training data found or parsed correctly.")

print("\nCounting total records in the validation dataset...")
counting_dataset = get_counting_dataset(base_type='validation_patches')
EVAL_SIZE = 0
for _ in counting_dataset:
    EVAL_SIZE += 1
print(f"Total validation records (EVAL_SIZE): {EVAL_SIZE}")

if EVAL_SIZE == 0:
    raise ValueError("TRAIN_SIZE is 0. No training data found or parsed correctly.")
# Out:
# Counting total records in the training dataset...
# Total training records (TRAIN_SIZE): 1000
#
# Counting total records in the validation dataset...
# Total validation records (EVAL_SIZE): 200

# %%
SUPERVISED[0] # Confirm label used
# Out:
# 'kmeans_validated_label'

# %%
PREVIEW_FREQUENCY = 10 # Display preview every N epochs
EPOCHS = 50
TRAIN_SIZE = TRAIN_SIZE # Use the counted size for steps_per_epoch

training_dataset = get_base_dataset()
validation_dataset = get_base_dataset(base_type='validation_patches')

preview_dataset = get_preview_dataset(num_batches=3) # Get 3 example batches

INITIAL_EPOCH = 0

# checkpoint_path = '//mnt/nfs/assets/dumpsites/checkpoints/final_supervised_label_v5/final_supervised_label-cp-{epoch:04d}.weights.h5' # Example path
checkpoint_path = '//mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-{epoch:04d}.weights.h5' # Example path

# checkpoint_path = '//mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label-cp-{epoch:04d}.weights.h5' # Example path

# model.load_weights(f'/mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/final_supervised_label-cp-00{INITIAL_EPOCH}.weights.h5') #uncomment if you want to join

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True, # Often better to save weights only for checkpoints
    save_best_only=False,
    save_freq=PREVIEW_FREQUENCY * int(TRAIN_SIZE / BATCH_SIZE)
)

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_mean_iou',
    min_delta=0.001,
    patience=15,
    mode='max',
    restore_best_weights=True
)

tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir="/mnt/nfs/assets/dumpsites/logs/" + SUPERVISED[0] + '_v5', #+ SAMPLE_VERSION,  # or another directory
    histogram_freq=1,  # logs weights every epoch
    write_graph=True,
    write_images=True,
)

img_callback = ImagePredictionCallback(preview_dataset=preview_dataset, frequency=PREVIEW_FREQUENCY, rgb_band_indices=[4, 3, 2]) # B8, B4, B3 for RGB

# training
# print("\nStarting model training...")
# history_supervised = model.fit(
#     x=training_dataset,
#     epochs=EPOCHS,
#     initial_epoch=INITIAL_EPOCH,
#     steps_per_epoch=int(TRAIN_SIZE / BATCH_SIZE),
#     verbose=1,
#     # callbacks=[cp_callback, es_callback, tensorboard_callback, img_callback],
#     callbacks=[cp_callback, tensorboard_callback, img_callback],
#     validation_data=validation_dataset,
#     validation_steps=EVAL_SIZE,
# )

# print("\nTraining complete!")

print("\nStarting model training...")
history_unsupervised = model.fit(
    x=training_dataset,
    epochs=EPOCHS,
    initial_epoch=INITIAL_EPOCH,
    steps_per_epoch=int(TRAIN_SIZE / BATCH_SIZE),
    verbose=1,
    # callbacks=[cp_callback, es_callback, tensorboard_callback, img_callback],
    callbacks=[cp_callback, tensorboard_callback, img_callback],
    validation_data=validation_dataset,
    validation_steps=EVAL_SIZE,
)

print("\nTraining complete!")
# Out:
# Starting model training...
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - accuracy: 0.9933 - loss: 0.0173 - mean_iou: 0.4960 - val_accuracy: 0.9967 - val_loss: 0.0090 - val_mean_iou: 0.4982
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9690 - loss: 368.7973 - mean_iou: 0.4898 - val_accuracy: 0.9963 - val_loss: 0.3327 - val_mean_iou: 0.4982
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9922 - loss: 0.1619 - mean_iou: 0.4961 - val_accuracy: 0.9964 - val_loss: 0.0243 - val_mean_iou: 0.4982
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9942 - loss: 0.0361 - mean_iou: 0.4971 - val_accuracy: 0.9964 - val_loss: 0.0236 - val_mean_iou: 0.4982
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9884 - loss: 0.0652 - mean_iou: 0.4942 - val_accuracy: 0.9964 - val_loss: 0.0246 - val_mean_iou: 0.4982
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9937 - loss: 0.0367 - mean_iou: 0.4969 - val_accuracy: 0.9964 - val_loss: 0.0186 - val_mean_iou: 0.4982
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 216ms/step - accuracy: 0.9937 - loss: 0.0321 - mean_iou: 0.5048 - val_accuracy: 0.9965 - val_loss: 0.0152 - val_mean_iou: 0.4982
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9936 - loss: 0.0294 - mean_iou: 0.4968 - val_accuracy: 0.9963 - val_loss: 0.0131 - val_mean_iou: 0.4982
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9929 - loss: 0.0254 - mean_iou: 0.4964 - val_accuracy: 0.9963 - val_loss: 0.0119 - val_mean_iou: 0.4982
# Epoch 10/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9935 - loss: 0.0215 - mean_iou: 0.5131
# Epoch 10: saving model to //mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-0010.weights.h5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9935 - loss: 0.0215 - mean_iou: 0.5129
# --- Previewing predictions at Epoch 10 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 18s 291ms/step - accuracy: 0.9935 - loss: 0.0215 - mean_iou: 0.5126 - val_accuracy: 0.9964 - val_loss: 0.0116 - val_mean_iou: 0.4982
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9943 - loss: 0.0219 - mean_iou: 0.5051 - val_accuracy: 0.9964 - val_loss: 0.0115 - val_mean_iou: 0.4982
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9939 - loss: 0.0203 - mean_iou: 0.5049 - val_accuracy: 0.9964 - val_loss: 0.0115 - val_mean_iou: 0.4982
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - accuracy: 0.9946 - loss: 0.0203 - mean_iou: 0.5052 - val_accuracy: 0.9964 - val_loss: 0.0121 - val_mean_iou: 0.4982
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9952 - loss: 0.0192 - mean_iou: 0.4976 - val_accuracy: 0.9964 - val_loss: 0.0118 - val_mean_iou: 0.4982
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9944 - loss: 0.0215 - mean_iou: 0.4972 - val_accuracy: 0.9964 - val_loss: 0.0123 - val_mean_iou: 0.4982
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9952 - loss: 0.0201 - mean_iou: 0.4976 - val_accuracy: 0.9963 - val_loss: 0.0114 - val_mean_iou: 0.4982
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9930 - loss: 0.0203 - mean_iou: 0.4965 - val_accuracy: 0.9964 - val_loss: 0.0126 - val_mean_iou: 0.4982
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 211ms/step - accuracy: 0.9943 - loss: 0.0223 - mean_iou: 0.4971 - val_accuracy: 0.9964 - val_loss: 0.0110 - val_mean_iou: 0.4982
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9922 - loss: 0.0238 - mean_iou: 0.4961 - val_accuracy: 0.9965 - val_loss: 0.0115 - val_mean_iou: 0.4982
# Epoch 20/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9943 - loss: 0.0174 - mean_iou: 0.4971
# Epoch 20: saving model to //mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-0020.weights.h5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9943 - loss: 0.0174 - mean_iou: 0.4971
# --- Previewing predictions at Epoch 20 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 18s 294ms/step - accuracy: 0.9943 - loss: 0.0174 - mean_iou: 0.4972 - val_accuracy: 0.9964 - val_loss: 0.0110 - val_mean_iou: 0.4982
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - accuracy: 0.9908 - loss: 0.0263 - mean_iou: 0.4954 - val_accuracy: 0.9964 - val_loss: 0.0110 - val_mean_iou: 0.4982
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9900 - loss: 0.0257 - mean_iou: 0.5030 - val_accuracy: 0.9964 - val_loss: 0.0116 - val_mean_iou: 0.4982
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 212ms/step - accuracy: 0.9921 - loss: 0.0215 - mean_iou: 0.4960 - val_accuracy: 0.9964 - val_loss: 0.0103 - val_mean_iou: 0.4982
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9895 - loss: 0.0259 - mean_iou: 0.4947 - val_accuracy: 0.9964 - val_loss: 0.0112 - val_mean_iou: 0.4982
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 212ms/step - accuracy: 0.9919 - loss: 0.0191 - mean_iou: 0.4960 - val_accuracy: 0.9964 - val_loss: 0.0123 - val_mean_iou: 0.4982
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 212ms/step - accuracy: 0.9932 - loss: 0.0172 - mean_iou: 0.4966 - val_accuracy: 0.9964 - val_loss: 0.0098 - val_mean_iou: 0.4982
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9934 - loss: 0.0174 - mean_iou: 0.5046 - val_accuracy: 0.9964 - val_loss: 0.0100 - val_mean_iou: 0.4982
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - accuracy: 0.9924 - loss: 0.0179 - mean_iou: 0.5041 - val_accuracy: 0.9964 - val_loss: 0.0098 - val_mean_iou: 0.4982
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9924 - loss: 0.0168 - mean_iou: 0.4962 - val_accuracy: 0.9964 - val_loss: 0.0101 - val_mean_iou: 0.4982
# Epoch 30/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9920 - loss: 0.0186 - mean_iou: 0.4960
# Epoch 30: saving model to //mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-0030.weights.h5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9920 - loss: 0.0186 - mean_iou: 0.4960
# --- Previewing predictions at Epoch 30 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 18s 292ms/step - accuracy: 0.9920 - loss: 0.0185 - mean_iou: 0.4960 - val_accuracy: 0.9965 - val_loss: 0.0096 - val_mean_iou: 0.4982
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9927 - loss: 0.0162 - mean_iou: 0.5043 - val_accuracy: 0.9964 - val_loss: 0.0105 - val_mean_iou: 0.4982
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9930 - loss: 0.0149 - mean_iou: 0.5203 - val_accuracy: 0.9964 - val_loss: 0.0099 - val_mean_iou: 0.4982
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 212ms/step - accuracy: 0.9927 - loss: 0.0158 - mean_iou: 0.4964 - val_accuracy: 0.9964 - val_loss: 0.0109 - val_mean_iou: 0.4982
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9942 - loss: 0.0138 - mean_iou: 0.5130 - val_accuracy: 0.9964 - val_loss: 0.0098 - val_mean_iou: 0.4982
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9929 - loss: 0.0171 - mean_iou: 0.5282 - val_accuracy: 0.9965 - val_loss: 0.0099 - val_mean_iou: 0.4982
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9945 - loss: 0.0144 - mean_iou: 0.5052 - val_accuracy: 0.9963 - val_loss: 0.0098 - val_mean_iou: 0.4982
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9927 - loss: 0.0160 - mean_iou: 0.4964 - val_accuracy: 0.9963 - val_loss: 0.0099 - val_mean_iou: 0.4981
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9943 - loss: 0.0140 - mean_iou: 0.4971 - val_accuracy: 0.9964 - val_loss: 0.0105 - val_mean_iou: 0.4982
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9949 - loss: 0.0128 - mean_iou: 0.5054 - val_accuracy: 0.9963 - val_loss: 0.0099 - val_mean_iou: 0.4982
# Epoch 40/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9948 - loss: 0.0134 - mean_iou: 0.4974
# Epoch 40: saving model to //mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-0040.weights.h5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9947 - loss: 0.0134 - mean_iou: 0.4974
# --- Previewing predictions at Epoch 40 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 18s 299ms/step - accuracy: 0.9947 - loss: 0.0134 - mean_iou: 0.4974 - val_accuracy: 0.9964 - val_loss: 0.0105 - val_mean_iou: 0.4982
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 216ms/step - accuracy: 0.9951 - loss: 0.0133 - mean_iou: 0.5055 - val_accuracy: 0.9964 - val_loss: 0.0105 - val_mean_iou: 0.4982
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9941 - loss: 0.0150 - mean_iou: 0.4971 - val_accuracy: 0.9964 - val_loss: 0.0098 - val_mean_iou: 0.4982
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9944 - loss: 0.0134 - mean_iou: 0.5051 - val_accuracy: 0.9964 - val_loss: 0.0100 - val_mean_iou: 0.4982
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 212ms/step - accuracy: 0.9931 - loss: 0.0166 - mean_iou: 0.4966 - val_accuracy: 0.9964 - val_loss: 0.0096 - val_mean_iou: 0.4982
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9934 - loss: 0.0151 - mean_iou: 0.4967 - val_accuracy: 0.9964 - val_loss: 0.0110 - val_mean_iou: 0.4982
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 213ms/step - accuracy: 0.9947 - loss: 0.0140 - mean_iou: 0.4974 - val_accuracy: 0.9964 - val_loss: 0.0097 - val_mean_iou: 0.4982
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.9947 - loss: 0.0136 - mean_iou: 0.4973 - val_accuracy: 0.9964 - val_loss: 0.0100 - val_mean_iou: 0.4982
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 217ms/step - accuracy: 0.9942 - loss: 0.0143 - mean_iou: 0.4971 - val_accuracy: 0.9963 - val_loss: 0.0104 - val_mean_iou: 0.4982
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - accuracy: 0.9954 - loss: 0.0136 - mean_iou: 0.5136 - val_accuracy: 0.9963 - val_loss: 0.0113 - val_mean_iou: 0.4982
# Epoch 50/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9957 - loss: 0.0122 - mean_iou: 0.5060
# Epoch 50: saving model to //mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-0050.weights.h5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9956 - loss: 0.0123 - mean_iou: 0.5059
# --- Previewing predictions at Epoch 50 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 18s 294ms/step - accuracy: 0.9956 - loss: 0.0123 - mean_iou: 0.5057 - val_accuracy: 0.9964 - val_loss: 0.0098 - val_mean_iou: 0.4982
#
# Training complete!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data
history_1 = history_supervised.history
history_2 = history_unsupervised.history

# epochs = list(range(1, len(history_1['loss']) + 1))

# # Create DataFrame for loss
# loss_df = pd.DataFrame({
#     'Epoch': epochs,
#     'Train Loss': history_1['loss'],
#     'Val Loss': history_1['val_loss']
# })
# loss_df = loss_df.melt(id_vars='Epoch', var_name='Set', value_name='Loss')

# # Plot loss
# plt.figure(figsize=(8, 5))
# sns.lineplot(data=loss_df, x='Epoch', y='Loss', hue='Set', style='Set',
#              markers=True, palette=['#ff4040ff', '#3a8eedff'])
# plt.title('Loss over Epochs')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# # Plot accuracy if available
# if 'accuracy' in history_1 and 'val_accuracy' in history_1:
#     acc_df = pd.DataFrame({
#         'Epoch': epochs,
#         'Train Accuracy': history_1['accuracy'],
#         'Val Accuracy': history_1['val_accuracy']
#     })
#     acc_df = acc_df.melt(id_vars='Epoch', var_name='Set', value_name='Accuracy')

#     plt.figure(figsize=(8, 5))
#     sns.lineplot(data=acc_df, x='Epoch', y='Accuracy', hue='Set', style='Set',
#                  markers=True, palette=['#ff4040ff', '#3a8eedff'])
#     plt.title('Accuracy over Epochs')
#     plt.ylabel('Accuracy')
#     plt.xlabel('Epoch')
#     plt.grid(True)
#     plt.tight_layout()
#     plt.show()

# %%
import pandas as pd

# Epoch to compare (Python is 0-based, so epoch 50 is index 49)
epoch = 49

# Define the metrics you want to compare
metrics = ['loss', 'val_loss', 'accuracy', 'val_accuracy', 'mean_iou', 'val_mean_iou']

# Helper to extract value if it exists
def get_metric(history, metric, epoch):
    try:
        return history[metric][epoch]
    except (KeyError, IndexError):
        return None

# Build comparison table
data = []
for metric in metrics:
    row = {
        'Metric': metric,
        'Model 1': get_metric(history_1, metric, epoch),
        'Model 2': get_metric(history_2, metric, epoch)
    }
    data.append(row)

comparison_df = pd.DataFrame(data)
comparison_df = comparison_df.dropna(how='all', subset=['Model 1', 'Model 2'])  # drop empty rows

# Display table
print(comparison_df)
# Out:
#          Metric   Model 1   Model 2
# 0          loss  0.016508  0.015608
# 1      val_loss  0.012697  0.009772
# 2      accuracy  0.993474  0.992615
# 3  val_accuracy  0.995477  0.996400
# 4      mean_iou  0.496655  0.496307
# 5  val_mean_iou  0.498253  0.498200

# %%
import pickle
import os

# Create output directory if needed
output_dir = "/mnt/nfs/assets/dumpsites/histories/"
os.makedirs(output_dir, exist_ok=True)

# Save both histories
with open(os.path.join(output_dir, 'history_model_1.pkl'), 'wb') as f:
    pickle.dump(history_1, f)

with open(os.path.join(output_dir, 'history_model_2.pkl'), 'wb') as f:
    pickle.dump(history_2, f)

print("Histories saved.")
# Out:
# Histories saved.

# %% [markdown]
# ### Prediction
# After training and saving each model, we will use each one for predicting possible aggregations of waste for different areas. <br>
# First, I am going to create a grid over my interest area (MRSP) of 1300 x 1300 m, where each geometry will be used to extract a 128 x 128 px patch to input into our model

# %%
# Load the region of interest
# roi = ee.FeatureCollection('FAO/GAUL_SIMPLIFIED_500m/2015/level1').filter(ee.Filter.eq('ADM1_NAME','Sao Paulo'));
roi = ee.FeatureCollection("users/julcansado/TFG/BASES/MUN_RMSP")
# Parameters
patch_size = 1300  # meters (e.g., 128 px * 10m/px)
overlap = 0.05      # 30% overlap
stride = patch_size * (1 - overlap) # Calculate stride in meters

target_projection_crs = 'EPSG:32723'

# --- Grid Generation Function ---
def generate_grid(region_wgs84, scale_meters, stride_meters, projection_crs):
    """
    Generates a grid of overlapping patches over a given region.
    The grid calculations are performed in a specified projected coordinate system (CRS)
    to ensure accurate handling of meter-based `scale_meters` and `stride_meters`.

    Args:
        region_wgs84 (ee.Geometry): The input region, expected to be in WGS84 (degrees).
        scale_meters (float): The desired side length of each square patch in meters.
        stride_meters (float): The step size (distance between patch origins) in meters.
                               This incorporates the overlap.
        projection_crs (str): The EPSG code of the target projected coordinate system
                              (e.g., 'EPSG:32723' for UTM Zone 23S).

    Returns:
        ee.FeatureCollection: A FeatureCollection where each feature is a grid cell
                              (ee.Geometry.Rectangle) in the specified `projection_crs`.
    """
    # 1. Reproject the input region to the target projected CRS.
    #    This ensures that all subsequent coordinate calculations are in meters.
    #    A small `maxError` (0.01 meters) is used for precision during transformation.
    region_projected = region_wgs84.transform(projection_crs, 0.01)

    # 2. Get the bounding box of the reprojected region.
    #    It's crucial to specify the `crs` argument here to get bounds in meters.
    bounds_projected = region_projected.bounds(1, projection_crs) # 1 meter error margin

    # 3. Extract the min/max coordinates (in meters) from the projected bounds.
    #    The bounds() method returns a rectangle's coordinates as a list of lists.
    coords = bounds_projected.coordinates().get(0) # Get the first vertex of the bounding box

    # Extract xmin, ymin, xmax, ymax from the bounding box coordinates.
    # For a rectangle, the first point is [xmin, ymin] and the third is [xmax, ymax].
    xmin = ee.Number(ee.List(ee.List(coords).get(0)).get(0)) # x-coord of first point
    ymin = ee.Number(ee.List(ee.List(coords).get(0)).get(1)) # y-coord of first point
    xmax = ee.Number(ee.List(ee.List(coords).get(2)).get(0)) # x-coord of third point
    ymax = ee.Number(ee.List(ee.List(coords).get(2)).get(1)) # y-coord of third point

    # 4. Generate sequences of x and y coordinates for the grid origins.
    #    We subtract `scale_meters` from `xmax`/`ymax` and add `stride_meters`
    #    to ensure the last patch starts within the region and covers it,
    #    accounting for the patch size and stride.
    x_coords = ee.List.sequence(xmin, xmax.subtract(scale_meters).add(stride_meters), stride_meters)
    y_coords = ee.List.sequence(ymin, ymax.subtract(scale_meters).add(stride_meters), stride_meters)

    # 5. Define a nested function to create a feature for each grid cell.
    def make_feature(x):
        def make_row(y):
            x0 = ee.Number(x)
            y0 = ee.Number(y)
            # Create the rectangle for the cell.
            # Specify the `projection_crs` to ensure it's created in meters.
            # `False` for `geodesic` ensures a planar rectangle, suitable for projected CRS.
            cell = ee.Geometry.Rectangle([
                x0, y0,
                x0.add(scale_meters), y0.add(scale_meters)
            ], projection_crs, False)
            return ee.Feature(cell)
        # Map `make_row` over the y_coords to create a row of cells for the current x.
        return y_coords.map(make_row)

    # 6. Map `make_feature` over the x_coords to create all rows of cells,
    #    then flatten the list of lists into a single list of features.
    cells = x_coords.map(lambda x: make_feature(x))
    return ee.FeatureCollection(cells.flatten())

# --- Generate the Grid ---
print(f"Generating grid with patch size: {patch_size}m, overlap: {overlap*100}%, stride: {stride}m")
print(f"Region will be reprojected to: {target_projection_crs}")
grid_fc = generate_grid(roi.geometry(), patch_size, stride, target_projection_crs)
print(f"Grid generated. Number of patches: {grid_fc.size().getInfo()}")


task = ee.batch.Export.table.toDrive(collection=grid_fc,
                                     description='grid_patches_export_RMSP',
                                     folder='EarthEngine_Exports_2', # Optional: specify a folder in your Drive
                                     fileNamePrefix='grid_patches_RMSP',
                                     fileFormat='SHP') # Or 'CSV', 'SHP', 'KML'

# Start the export task
# task.start()

print("Export task started. Check your Earth Engine Tasks tab (https://code.earthengine.google.com/tasks) for progress and your Google Drive.")
# Out:
# Generating grid with patch size: 1300m, overlap: 5.0%, stride: 1235.0m
# Region will be reprojected to: EPSG:32723
# Grid generated. Number of patches: 14750
# Export task started. Check your Earth Engine Tasks tab (https://code.earthengine.google.com/tasks) for progress and your Google Drive.

# %% [markdown]
# There were 14750 grids total, but I opened it in Earth Engine and only selected those who overlap with MRSP - the grid was created over the region's bounds, so we have many extra geometries we don't need to predict.
# In the next cell, we start the exporting of 7171 geotiff patches to predict (they'll be going to my Google Drive).
#
# PS.: This is approximately 5GB of data.

# %%
# --- 1. Prepare Image ---
# Load your GEE mosaic asset
gee_mosaic = ee.Image('projects/dumpsites-id/assets/mosaic_v4')

band_names = BANDS 

input_image = gee_mosaic.select(band_names).toFloat()
# normalized_image = input_image.divide(10000.0) # Example: assuming 16-bit data scaled to 0-1

# --- 2. Load Your Grid FeatureCollection ---
# This is the asset ID of your grid
grid_fc = ee.FeatureCollection('projects/dumpsites-id/assets/grid_RMSP_v2_filter')

# Define the Google Drive folder for the output files
drive_folder = 'tiles_to_predict_RMSP' # This folder will be created in your Google Drive root

# --- 3. Iterate and Launch Export Tasks ---
# Get the grid as a client-side list to iterate over
grid_list = grid_fc.toList(grid_fc.size())
number_of_features = grid_list.size().getInfo()

# number_of_features = 10
print(f"Found {number_of_features} grid cells to export.")

# # WARNING: This loop will launch a separate export task for EACH feature in your grid.
# # Check your GEE Tasks tab to monitor them.
for i in range(number_of_features):
    feature = ee.Feature(grid_list.get(i))
    geom = feature.geometry()
    tile = input_image.clip(geom)

    file_name = f'image_tile_{i:03d}'

    task = ee.batch.Export.image.toDrive(
        image=tile,
        description=file_name,
        folder=drive_folder,
        fileNamePrefix=file_name,
        region=geom.bounds().getInfo()['coordinates'],
        scale=10,
        maxPixels=1e13,
        fileFormat='GeoTIFF',
        formatOptions={'cloudOptimized': True}
    )

    task.start()
    print(f'Started export: {file_name}')
# Out:
# Found 7171 grid cells to export.
# Started export: image_tile_000
# Started export: image_tile_001
# Started export: image_tile_002
# Started export: image_tile_003
# Started export: image_tile_004
# Started export: image_tile_005
# Started export: image_tile_006
# Started export: image_tile_007
# Started export: image_tile_008
# Started export: image_tile_009
# Started export: image_tile_010
# Started export: image_tile_011
# Started export: image_tile_012
# Started export: image_tile_013
# Started export: image_tile_014
# Started export: image_tile_015
# Started export: image_tile_016
# Started export: image_tile_017
# Started export: image_tile_018
# Started export: image_tile_019
# Started export: image_tile_020
# Started export: image_tile_021
# Started export: image_tile_022
# Started export: image_tile_023
# Started export: image_tile_024
# Started export: image_tile_025
# Started export: image_tile_026
# Started export: image_tile_027
# Started export: image_tile_028
# Started export: image_tile_029
# Started export: image_tile_030
# Started export: image_tile_031
# Started export: image_tile_032
# Started export: image_tile_033
# Started export: image_tile_034
# Started export: image_tile_035
# Started export: image_tile_036
# Started export: image_tile_037
# Started export: image_tile_038
# Started export: image_tile_039
# Started export: image_tile_040
# Started export: image_tile_041
# Started export: image_tile_042
# Started export: image_tile_043
# Started export: image_tile_044
# Started export: image_tile_045
# Started export: image_tile_046
# Started export: image_tile_047
# Started export: image_tile_048
# Started export: image_tile_049
# Started export: image_tile_050
# Started export: image_tile_051
# Started export: image_tile_052
# Started export: image_tile_053
# Started export: image_tile_054
# Started export: image_tile_055
# Started export: image_tile_056
# Started export: image_tile_057
# Started export: image_tile_058
# Started export: image_tile_059
# Started export: image_tile_060
# Started export: image_tile_061
# Started export: image_tile_062
# Started export: image_tile_063
# Started export: image_tile_064
# Started export: image_tile_065
# Started export: image_tile_066
# Started export: image_tile_067
# Started export: image_tile_068
# Started export: image_tile_069
# Started export: image_tile_070
# Started export: image_tile_071
# Started export: image_tile_072
# Started export: image_tile_073
# Started export: image_tile_074
# Started export: image_tile_075
# Started export: image_tile_076
# Started export: image_tile_077
# Started export: image_tile_078
# Started export: image_tile_079
# Started export: image_tile_080
# Started export: image_tile_081
# Started export: image_tile_082
# Started export: image_tile_083
# Started export: image_tile_084
# Started export: image_tile_085
# Started export: image_tile_086
# Started export: image_tile_087
# Started export: image_tile_088
# Started export: image_tile_089
# Started export: image_tile_090
# Started export: image_tile_091
# Started export: image_tile_092
# Started export: image_tile_093
# Started export: image_tile_094
# Started export: image_tile_095
# Started export: image_tile_096
# Started export: image_tile_097
# Started export: image_tile_098
# Started export: image_tile_099
# Started export: image_tile_100
# Started export: image_tile_101
# Started export: image_tile_102
# Started export: image_tile_103
# Started export: image_tile_104
# Started export: image_tile_105
# Started export: image_tile_106
# Started export: image_tile_107
# Started export: image_tile_108
# Started export: image_tile_109
# Started export: image_tile_110
# Started export: image_tile_111
# Started export: image_tile_112
# Started export: image_tile_113
# Started export: image_tile_114
# Started export: image_tile_115
# Started export: image_tile_116
# Started export: image_tile_117
# Started export: image_tile_118
# Started export: image_tile_119
# Started export: image_tile_120
# Started export: image_tile_121
# Started export: image_tile_122
# Started export: image_tile_123
# Started export: image_tile_124
# Started export: image_tile_125
# Started export: image_tile_126
# Started export: image_tile_127
# Started export: image_tile_128
# Started export: image_tile_129
# Started export: image_tile_130
# Started export: image_tile_131
# Started export: image_tile_132
# Started export: image_tile_133
# Started export: image_tile_134
# Started export: image_tile_135
# Started export: image_tile_136
# Started export: image_tile_137
# Started export: image_tile_138
# Started export: image_tile_139
# Started export: image_tile_140
# Started export: image_tile_141
# Started export: image_tile_142
# Started export: image_tile_143
# Started export: image_tile_144
# Started export: image_tile_145
# Started export: image_tile_146
# Started export: image_tile_147
# Started export: image_tile_148
# Started export: image_tile_149
# Started export: image_tile_150
# Started export: image_tile_151
# Started export: image_tile_152
# Started export: image_tile_153
# Started export: image_tile_154
# Started export: image_tile_155
# Started export: image_tile_156
# Started export: image_tile_157
# Started export: image_tile_158
# Started export: image_tile_159
# Started export: image_tile_160
# Started export: image_tile_161
# Started export: image_tile_162
# Started export: image_tile_163
# Started export: image_tile_164
# Started export: image_tile_165
# Started export: image_tile_166
# Started export: image_tile_167
# Started export: image_tile_168
# Started export: image_tile_169
# Started export: image_tile_170
# Started export: image_tile_171
# Started export: image_tile_172
# Started export: image_tile_173
# Started export: image_tile_174
# Started export: image_tile_175
# Started export: image_tile_176
# Started export: image_tile_177
# Started export: image_tile_178
# Started export: image_tile_179
# Started export: image_tile_180
# Started export: image_tile_181
# Started export: image_tile_182
# Started export: image_tile_183
# Started export: image_tile_184
# Started export: image_tile_185
# Started export: image_tile_186
# Started export: image_tile_187
# Started export: image_tile_188
# Started export: image_tile_189
# Started export: image_tile_190
# Started export: image_tile_191
# Started export: image_tile_192
# Started export: image_tile_193
# Started export: image_tile_194
# Started export: image_tile_195
# Started export: image_tile_196
# Started export: image_tile_197
# Started export: image_tile_198
# Started export: image_tile_199
# Started export: image_tile_200
# Started export: image_tile_201
# Started export: image_tile_202
# Started export: image_tile_203
# Started export: image_tile_204
# Started export: image_tile_205
# Started export: image_tile_206
# Started export: image_tile_207
# Started export: image_tile_208
# Started export: image_tile_209
# Started export: image_tile_210
# Started export: image_tile_211
# Started export: image_tile_212
# Started export: image_tile_213
# Started export: image_tile_214
# Started export: image_tile_215
# Started export: image_tile_216
# Started export: image_tile_217
# Started export: image_tile_218
# Started export: image_tile_219
# Started export: image_tile_220
# Started export: image_tile_221
# Started export: image_tile_222
# Started export: image_tile_223
# Started export: image_tile_224
# Started export: image_tile_225
# Started export: image_tile_226
# Started export: image_tile_227
# Started export: image_tile_228
# Started export: image_tile_229
# Started export: image_tile_230
# Started export: image_tile_231
# Started export: image_tile_232
# Started export: image_tile_233
# Started export: image_tile_234
# Started export: image_tile_235
# Started export: image_tile_236
# Started export: image_tile_237
# Started export: image_tile_238
# Started export: image_tile_239
# Started export: image_tile_240
# Started export: image_tile_241
# Started export: image_tile_242
# Started export: image_tile_243
# Started export: image_tile_244
# Started export: image_tile_245
# Started export: image_tile_246
# Started export: image_tile_247
# Started export: image_tile_248
# Started export: image_tile_249
# Started export: image_tile_250
# Started export: image_tile_251
# Started export: image_tile_252
# Started export: image_tile_253
# Started export: image_tile_254
# Started export: image_tile_255
# Started export: image_tile_256
# Started export: image_tile_257
# Started export: image_tile_258
# Started export: image_tile_259
# Started export: image_tile_260
# Started export: image_tile_261
# Started export: image_tile_262
# Started export: image_tile_263
# Started export: image_tile_264
# Started export: image_tile_265
# Started export: image_tile_266
# Started export: image_tile_267
# Started export: image_tile_268
# Started export: image_tile_269
# Started export: image_tile_270
# Started export: image_tile_271
# Started export: image_tile_272
# Started export: image_tile_273
# Started export: image_tile_274
# Started export: image_tile_275
# Started export: image_tile_276
# Started export: image_tile_277
# Started export: image_tile_278
# Started export: image_tile_279
# Started export: image_tile_280
# Started export: image_tile_281
# Started export: image_tile_282
# Started export: image_tile_283
# Started export: image_tile_284
# Started export: image_tile_285
# Started export: image_tile_286
# Started export: image_tile_287
# Started export: image_tile_288
# Started export: image_tile_289
# Started export: image_tile_290
# Started export: image_tile_291
# Started export: image_tile_292
# Started export: image_tile_293
# Started export: image_tile_294
# Started export: image_tile_295
# Started export: image_tile_296
# Started export: image_tile_297
# Started export: image_tile_298
# Started export: image_tile_299
# Started export: image_tile_300
# Started export: image_tile_301
# Started export: image_tile_302
# Started export: image_tile_303
# Started export: image_tile_304
# Started export: image_tile_305
# Started export: image_tile_306
# Started export: image_tile_307
# Started export: image_tile_308
# Started export: image_tile_309
# Started export: image_tile_310
# Started export: image_tile_311
# Started export: image_tile_312
# Started export: image_tile_313
# Started export: image_tile_314
# Started export: image_tile_315
# Started export: image_tile_316
# Started export: image_tile_317
# Started export: image_tile_318
# Started export: image_tile_319
# Started export: image_tile_320
# Started export: image_tile_321
# Started export: image_tile_322
# Started export: image_tile_323
# Started export: image_tile_324
# Started export: image_tile_325
# Started export: image_tile_326
# Started export: image_tile_327
# Started export: image_tile_328
# Started export: image_tile_329
# Started export: image_tile_330
# Started export: image_tile_331
# Started export: image_tile_332
# Started export: image_tile_333
# Started export: image_tile_334
# Started export: image_tile_335
# Started export: image_tile_336
# Started export: image_tile_337
# Started export: image_tile_338
# Started export: image_tile_339
# Started export: image_tile_340
# Started export: image_tile_341
# Started export: image_tile_342
# Started export: image_tile_343
# Started export: image_tile_344
# Started export: image_tile_345
# Started export: image_tile_346
# Started export: image_tile_347
# Started export: image_tile_348
# Started export: image_tile_349
# Started export: image_tile_350
# Started export: image_tile_351
# Started export: image_tile_352
# Started export: image_tile_353
# Started export: image_tile_354
# Started export: image_tile_355
# Started export: image_tile_356
# Started export: image_tile_357
# Started export: image_tile_358
# Started export: image_tile_359
# Started export: image_tile_360
# Started export: image_tile_361
# Started export: image_tile_362
# Started export: image_tile_363
# Started export: image_tile_364
# Started export: image_tile_365
# Started export: image_tile_366
# Started export: image_tile_367
# Started export: image_tile_368
# Started export: image_tile_369
# Started export: image_tile_370
# Started export: image_tile_371
# Started export: image_tile_372
# Started export: image_tile_373
# Started export: image_tile_374
# Started export: image_tile_375
# Started export: image_tile_376
# Started export: image_tile_377
# Started export: image_tile_378
# Started export: image_tile_379
# Started export: image_tile_380
# Started export: image_tile_381
# Started export: image_tile_382
# Started export: image_tile_383
# Started export: image_tile_384
# Started export: image_tile_385
# Started export: image_tile_386
# Started export: image_tile_387
# Started export: image_tile_388
# Started export: image_tile_389
# Started export: image_tile_390
# Started export: image_tile_391
# Started export: image_tile_392
# Started export: image_tile_393
# Started export: image_tile_394
# Started export: image_tile_395
# Started export: image_tile_396
# Started export: image_tile_397
# Started export: image_tile_398
# Started export: image_tile_399
# Started export: image_tile_400
# Started export: image_tile_401
# Started export: image_tile_402
# Started export: image_tile_403
# Started export: image_tile_404
# Started export: image_tile_405
# Started export: image_tile_406
# Started export: image_tile_407
# Started export: image_tile_408
# Started export: image_tile_409
# Started export: image_tile_410
# Started export: image_tile_411
# Started export: image_tile_412
# Started export: image_tile_413
# Started export: image_tile_414
# Started export: image_tile_415
# Started export: image_tile_416
# Started export: image_tile_417
# Started export: image_tile_418
# Started export: image_tile_419
# Started export: image_tile_420
# Started export: image_tile_421
# Started export: image_tile_422
# Started export: image_tile_423
# Started export: image_tile_424
# Started export: image_tile_425
# Started export: image_tile_426
# Started export: image_tile_427
# Started export: image_tile_428
# Started export: image_tile_429
# Started export: image_tile_430
# Started export: image_tile_431
# Started export: image_tile_432
# Started export: image_tile_433
# Started export: image_tile_434
# Started export: image_tile_435
# Started export: image_tile_436
# Started export: image_tile_437
# Started export: image_tile_438
# Started export: image_tile_439
# Started export: image_tile_440
# Started export: image_tile_441
# Started export: image_tile_442
# Started export: image_tile_443
# Started export: image_tile_444
# Started export: image_tile_445
# Started export: image_tile_446
# Started export: image_tile_447
# Started export: image_tile_448
# Started export: image_tile_449
# Started export: image_tile_450
# Started export: image_tile_451
# Started export: image_tile_452
# Started export: image_tile_453
# Started export: image_tile_454
# Started export: image_tile_455
# Started export: image_tile_456
# Started export: image_tile_457
# Started export: image_tile_458
# Started export: image_tile_459
# Started export: image_tile_460
# Started export: image_tile_461
# Started export: image_tile_462
# Started export: image_tile_463
# Started export: image_tile_464
# Started export: image_tile_465
# Started export: image_tile_466
# Started export: image_tile_467
# Started export: image_tile_468
# Started export: image_tile_469
# Started export: image_tile_470
# Started export: image_tile_471
# Started export: image_tile_472
# Started export: image_tile_473
# Started export: image_tile_474
# Started export: image_tile_475
# Started export: image_tile_476
# Started export: image_tile_477
# Started export: image_tile_478
# Started export: image_tile_479
# Started export: image_tile_480
# Started export: image_tile_481
# Started export: image_tile_482
# Started export: image_tile_483
# Started export: image_tile_484
# Started export: image_tile_485
# Started export: image_tile_486
# Started export: image_tile_487
# Started export: image_tile_488
# Started export: image_tile_489
# Started export: image_tile_490
# Started export: image_tile_491
# Started export: image_tile_492
# Started export: image_tile_493
# Started export: image_tile_494
# Started export: image_tile_495
# Started export: image_tile_496
# Started export: image_tile_497
# Started export: image_tile_498
# Started export: image_tile_499
# Started export: image_tile_500
# Started export: image_tile_501
# Started export: image_tile_502
# Started export: image_tile_503
# Started export: image_tile_504
# Started export: image_tile_505
# Started export: image_tile_506
# Started export: image_tile_507
# Started export: image_tile_508
# Started export: image_tile_509
# Started export: image_tile_510
# Started export: image_tile_511
# Started export: image_tile_512
# Started export: image_tile_513
# Started export: image_tile_514
# Started export: image_tile_515
# Started export: image_tile_516
# Started export: image_tile_517
# Started export: image_tile_518
# Started export: image_tile_519
# Started export: image_tile_520
# Started export: image_tile_521
# Started export: image_tile_522
# Started export: image_tile_523
# Started export: image_tile_524
# Started export: image_tile_525
# Started export: image_tile_526
# Started export: image_tile_527
# Started export: image_tile_528
# Started export: image_tile_529
# Started export: image_tile_530
# Started export: image_tile_531
# Started export: image_tile_532
# Started export: image_tile_533
# Started export: image_tile_534
# Started export: image_tile_535
# Started export: image_tile_536
# Started export: image_tile_537
# Started export: image_tile_538
# Started export: image_tile_539
# Started export: image_tile_540
# Started export: image_tile_541
# Started export: image_tile_542
# Started export: image_tile_543
# Started export: image_tile_544
# Started export: image_tile_545
# Started export: image_tile_546
# Started export: image_tile_547
# Started export: image_tile_548
# Started export: image_tile_549
# Started export: image_tile_550
# Started export: image_tile_551
# Started export: image_tile_552
# Started export: image_tile_553
# Started export: image_tile_554
# Started export: image_tile_555
# Started export: image_tile_556
# Started export: image_tile_557
# Started export: image_tile_558
# Started export: image_tile_559
# Started export: image_tile_560
# Started export: image_tile_561
# Started export: image_tile_562
# Started export: image_tile_563
# Started export: image_tile_564
# Started export: image_tile_565
# Started export: image_tile_566
# Started export: image_tile_567
# Started export: image_tile_568
# Started export: image_tile_569
# Started export: image_tile_570
# Started export: image_tile_571
# Started export: image_tile_572
# Started export: image_tile_573
# Started export: image_tile_574
# Started export: image_tile_575
# Started export: image_tile_576
# Started export: image_tile_577
# Started export: image_tile_578
# Started export: image_tile_579
# Started export: image_tile_580
# Started export: image_tile_581
# Started export: image_tile_582
# Started export: image_tile_583
# Started export: image_tile_584
# Started export: image_tile_585
# Started export: image_tile_586
# Started export: image_tile_587
# Started export: image_tile_588
# Started export: image_tile_589
# Started export: image_tile_590
# Started export: image_tile_591
# Started export: image_tile_592
# Started export: image_tile_593
# Started export: image_tile_594
# Started export: image_tile_595
# Started export: image_tile_596
# Started export: image_tile_597
# Started export: image_tile_598
# Started export: image_tile_599
# Started export: image_tile_600
# Started export: image_tile_601
# Started export: image_tile_602
# Started export: image_tile_603
# Started export: image_tile_604
# Started export: image_tile_605
# Started export: image_tile_606
# Started export: image_tile_607
# Started export: image_tile_608
# Started export: image_tile_609
# Started export: image_tile_610
# Started export: image_tile_611
# Started export: image_tile_612
# Started export: image_tile_613
# Started export: image_tile_614
# Started export: image_tile_615
# Started export: image_tile_616
# Started export: image_tile_617
# Started export: image_tile_618
# Started export: image_tile_619
# Started export: image_tile_620
# Started export: image_tile_621
# Started export: image_tile_622
# Started export: image_tile_623
# Started export: image_tile_624
# Started export: image_tile_625
# Started export: image_tile_626
# Started export: image_tile_627
# Started export: image_tile_628
# Started export: image_tile_629
# Started export: image_tile_630
# Started export: image_tile_631
# Started export: image_tile_632
# Started export: image_tile_633
# Started export: image_tile_634
# Started export: image_tile_635
# Started export: image_tile_636
# Started export: image_tile_637
# Started export: image_tile_638
# Started export: image_tile_639
# Started export: image_tile_640
# Started export: image_tile_641
# Started export: image_tile_642
# Started export: image_tile_643
# Started export: image_tile_644
# Started export: image_tile_645
# Started export: image_tile_646
# Started export: image_tile_647
# Started export: image_tile_648
# Started export: image_tile_649
# Started export: image_tile_650
# Started export: image_tile_651
# Started export: image_tile_652
# Started export: image_tile_653
# Started export: image_tile_654
# Started export: image_tile_655
# Started export: image_tile_656
# Started export: image_tile_657
# Started export: image_tile_658
# Started export: image_tile_659
# Started export: image_tile_660
# Started export: image_tile_661
# Started export: image_tile_662
# Started export: image_tile_663
# Started export: image_tile_664
# Started export: image_tile_665
# Started export: image_tile_666
# Started export: image_tile_667
# Started export: image_tile_668
# Started export: image_tile_669
# Started export: image_tile_670
# Started export: image_tile_671
# Started export: image_tile_672
# Started export: image_tile_673
# Started export: image_tile_674
# Started export: image_tile_675
# Started export: image_tile_676
# Started export: image_tile_677
# Started export: image_tile_678
# Started export: image_tile_679
# Started export: image_tile_680
# Started export: image_tile_681
# Started export: image_tile_682
# Started export: image_tile_683
# Started export: image_tile_684
# Started export: image_tile_685
# Started export: image_tile_686
# Started export: image_tile_687
# Started export: image_tile_688
# Started export: image_tile_689
# Started export: image_tile_690
# Started export: image_tile_691
# Started export: image_tile_692
# Started export: image_tile_693
# Started export: image_tile_694
# Started export: image_tile_695
# Started export: image_tile_696
# Started export: image_tile_697
# Started export: image_tile_698
# Started export: image_tile_699
# Started export: image_tile_700
# Started export: image_tile_701
# Started export: image_tile_702
# Started export: image_tile_703
# Started export: image_tile_704
# Started export: image_tile_705
# Started export: image_tile_706
# Started export: image_tile_707
# Started export: image_tile_708
# Started export: image_tile_709
# Started export: image_tile_710
# Started export: image_tile_711
# Started export: image_tile_712
# Started export: image_tile_713
# Started export: image_tile_714
# Started export: image_tile_715
# Started export: image_tile_716
# Started export: image_tile_717
# Started export: image_tile_718
# Started export: image_tile_719
# Started export: image_tile_720
# Started export: image_tile_721
# Started export: image_tile_722
# Started export: image_tile_723
# Started export: image_tile_724
# Started export: image_tile_725
# Started export: image_tile_726
# Started export: image_tile_727
# Started export: image_tile_728
# Started export: image_tile_729
# Started export: image_tile_730
# Started export: image_tile_731
# Started export: image_tile_732
# Started export: image_tile_733
# Started export: image_tile_734
# Started export: image_tile_735
# Started export: image_tile_736
# Started export: image_tile_737
# Started export: image_tile_738
# Started export: image_tile_739
# Started export: image_tile_740
# Started export: image_tile_741
# Started export: image_tile_742
# Started export: image_tile_743
# Started export: image_tile_744
# Started export: image_tile_745
# Started export: image_tile_746
# Started export: image_tile_747
# Started export: image_tile_748
# Started export: image_tile_749
# Started export: image_tile_750
# Started export: image_tile_751
# Started export: image_tile_752
# Started export: image_tile_753
# Started export: image_tile_754
# Started export: image_tile_755
# Started export: image_tile_756
# Started export: image_tile_757
# Started export: image_tile_758
# Started export: image_tile_759
# Started export: image_tile_760
# Started export: image_tile_761
# Started export: image_tile_762
# Started export: image_tile_763
# Started export: image_tile_764
# Started export: image_tile_765
# Started export: image_tile_766
# Started export: image_tile_767
# Started export: image_tile_768
# Started export: image_tile_769
# Started export: image_tile_770
# Started export: image_tile_771
# Started export: image_tile_772
# Started export: image_tile_773
# Started export: image_tile_774
# Started export: image_tile_775
# Started export: image_tile_776
# Started export: image_tile_777
# Started export: image_tile_778
# Started export: image_tile_779
# Started export: image_tile_780
# Started export: image_tile_781
# Started export: image_tile_782
# Started export: image_tile_783
# Started export: image_tile_784
# Started export: image_tile_785
# Started export: image_tile_786
# Started export: image_tile_787
# Started export: image_tile_788
# Started export: image_tile_789
# Started export: image_tile_790
# Started export: image_tile_791
# Started export: image_tile_792
# Started export: image_tile_793
# Started export: image_tile_794
# Started export: image_tile_795
# Started export: image_tile_796
# Started export: image_tile_797
# Started export: image_tile_798
# Started export: image_tile_799
# Started export: image_tile_800
# Started export: image_tile_801
# Started export: image_tile_802
# Started export: image_tile_803
# Started export: image_tile_804
# Started export: image_tile_805
# Started export: image_tile_806
# Started export: image_tile_807
# Started export: image_tile_808
# Started export: image_tile_809
# Started export: image_tile_810
# Started export: image_tile_811
# Started export: image_tile_812
# Started export: image_tile_813
# Started export: image_tile_814
# Started export: image_tile_815
# Started export: image_tile_816
# Started export: image_tile_817
# Started export: image_tile_818
# Started export: image_tile_819
# Started export: image_tile_820
# Started export: image_tile_821
# Started export: image_tile_822
# Started export: image_tile_823
# Started export: image_tile_824
# Started export: image_tile_825
# Started export: image_tile_826
# Started export: image_tile_827
# Started export: image_tile_828
# Started export: image_tile_829
# Started export: image_tile_830
# Started export: image_tile_831
# Started export: image_tile_832
# Started export: image_tile_833
# Started export: image_tile_834
# Started export: image_tile_835
# Started export: image_tile_836
# Started export: image_tile_837
# Started export: image_tile_838
# Started export: image_tile_839
# Started export: image_tile_840
# Started export: image_tile_841
# Started export: image_tile_842
# Started export: image_tile_843
# Started export: image_tile_844
# Started export: image_tile_845
# Started export: image_tile_846
# Started export: image_tile_847
# Started export: image_tile_848
# Started export: image_tile_849
# Started export: image_tile_850
# Started export: image_tile_851
# Started export: image_tile_852
# Started export: image_tile_853
# Started export: image_tile_854
# Started export: image_tile_855
# Started export: image_tile_856
# Started export: image_tile_857
# Started export: image_tile_858
# Started export: image_tile_859
# Started export: image_tile_860
# Started export: image_tile_861
# Started export: image_tile_862
# Started export: image_tile_863
# Started export: image_tile_864
# Started export: image_tile_865
# Started export: image_tile_866
# Started export: image_tile_867
# Started export: image_tile_868
# Started export: image_tile_869
# Started export: image_tile_870
# Started export: image_tile_871
# Started export: image_tile_872
# Started export: image_tile_873
# Started export: image_tile_874
# Started export: image_tile_875
# Started export: image_tile_876
# Started export: image_tile_877
# Started export: image_tile_878
# Started export: image_tile_879
# Started export: image_tile_880
# Started export: image_tile_881
# Started export: image_tile_882
# Started export: image_tile_883
# Started export: image_tile_884
# Started export: image_tile_885
# Started export: image_tile_886
# Started export: image_tile_887
# Started export: image_tile_888
# Started export: image_tile_889
# Started export: image_tile_890
# Started export: image_tile_891
# Started export: image_tile_892
# Started export: image_tile_893
# Started export: image_tile_894
# Started export: image_tile_895
# Started export: image_tile_896
# Started export: image_tile_897
# Started export: image_tile_898
# Started export: image_tile_899
# Started export: image_tile_900
# Started export: image_tile_901
# Started export: image_tile_902
# Started export: image_tile_903
# Started export: image_tile_904
# Started export: image_tile_905
# Started export: image_tile_906
# Started export: image_tile_907
# Started export: image_tile_908
# Started export: image_tile_909
# Started export: image_tile_910
# Started export: image_tile_911
# Started export: image_tile_912
# Started export: image_tile_913
# Started export: image_tile_914
# Started export: image_tile_915
# Started export: image_tile_916
# Started export: image_tile_917
# Started export: image_tile_918
# Started export: image_tile_919
# Started export: image_tile_920
# Started export: image_tile_921
# Started export: image_tile_922
# Started export: image_tile_923
# Started export: image_tile_924
# Started export: image_tile_925
# Started export: image_tile_926
# Started export: image_tile_927
# Started export: image_tile_928
# Started export: image_tile_929
# Started export: image_tile_930
# Started export: image_tile_931
# Started export: image_tile_932
# Started export: image_tile_933
# Started export: image_tile_934
# Started export: image_tile_935
# Started export: image_tile_936
# Started export: image_tile_937
# Started export: image_tile_938
# Started export: image_tile_939
# Started export: image_tile_940
# Started export: image_tile_941
# Started export: image_tile_942
# Started export: image_tile_943
# Started export: image_tile_944
# Started export: image_tile_945
# Started export: image_tile_946
# Started export: image_tile_947
# Started export: image_tile_948
# Started export: image_tile_949
# Started export: image_tile_950
# Started export: image_tile_951
# Started export: image_tile_952
# Started export: image_tile_953
# Started export: image_tile_954
# Started export: image_tile_955
# Started export: image_tile_956
# Started export: image_tile_957
# Started export: image_tile_958
# Started export: image_tile_959
# Started export: image_tile_960
# Started export: image_tile_961
# Started export: image_tile_962
# Started export: image_tile_963
# Started export: image_tile_964
# Started export: image_tile_965
# Started export: image_tile_966
# Started export: image_tile_967
# Started export: image_tile_968
# Started export: image_tile_969
# Started export: image_tile_970
# Started export: image_tile_971
# Started export: image_tile_972
# Started export: image_tile_973
# Started export: image_tile_974
# Started export: image_tile_975
# Started export: image_tile_976
# Started export: image_tile_977
# Started export: image_tile_978
# Started export: image_tile_979
# Started export: image_tile_980
# Started export: image_tile_981
# Started export: image_tile_982
# Started export: image_tile_983
# Started export: image_tile_984
# Started export: image_tile_985
# Started export: image_tile_986
# Started export: image_tile_987
# Started export: image_tile_988
# Started export: image_tile_989
# Started export: image_tile_990
# Started export: image_tile_991
# Started export: image_tile_992
# Started export: image_tile_993
# Started export: image_tile_994
# Started export: image_tile_995
# Started export: image_tile_996
# Started export: image_tile_997
# Started export: image_tile_998
# Started export: image_tile_999
# Started export: image_tile_1000
# Started export: image_tile_1001
# Started export: image_tile_1002
# Started export: image_tile_1003
# Started export: image_tile_1112
# Started export: image_tile_1113
# Started export: image_tile_1114
# Started export: image_tile_1115
# Started export: image_tile_1116
# Started export: image_tile_1117
# Started export: image_tile_1118
# Started export: image_tile_1119
# Started export: image_tile_1120
# Started export: image_tile_1121
# Started export: image_tile_1122
# Started export: image_tile_1123
# Started export: image_tile_1124
# Started export: image_tile_1125
# Started export: image_tile_1126
# Started export: image_tile_1127
# Started export: image_tile_1128
# Started export: image_tile_1129
# Started export: image_tile_1130
# Started export: image_tile_1131
# Started export: image_tile_1132
# Started export: image_tile_1133
# Started export: image_tile_1134
# Started export: image_tile_1135
# Started export: image_tile_1136
# Started export: image_tile_1137
# Started export: image_tile_1138
# Started export: image_tile_1139
# Started export: image_tile_1140
# Started export: image_tile_1141
# Started export: image_tile_1142
# Started export: image_tile_1143
# Started export: image_tile_1144
# Started export: image_tile_1145
# Started export: image_tile_1146
# Started export: image_tile_1147
# Started export: image_tile_1148
# Started export: image_tile_1149
# Started export: image_tile_1150
# Started export: image_tile_1151
# Started export: image_tile_1152
# Started export: image_tile_1153
# Started export: image_tile_1154
# Started export: image_tile_1155
# Started export: image_tile_1156
# Started export: image_tile_1157
# Started export: image_tile_1158
# Started export: image_tile_1159
# Started export: image_tile_1160
# Started export: image_tile_1161
# Started export: image_tile_1162
# Started export: image_tile_1163
# Started export: image_tile_1164
# Started export: image_tile_1165
# Started export: image_tile_1166
# Started export: image_tile_1167
# Started export: image_tile_1168
# Started export: image_tile_1169
# Started export: image_tile_1170
# Started export: image_tile_1171
# Started export: image_tile_1172
# Started export: image_tile_1173
# Started export: image_tile_1174
# Started export: image_tile_1175
# Started export: image_tile_1176
# Started export: image_tile_1177
# Started export: image_tile_1178
# Started export: image_tile_1179
# Started export: image_tile_1180
# Started export: image_tile_1181
# Started export: image_tile_1182
# Started export: image_tile_1183
# Started export: image_tile_1184
# Started export: image_tile_1185
# Started export: image_tile_1186
# Started export: image_tile_1187
# Started export: image_tile_1188
# Started export: image_tile_1189
# Started export: image_tile_1190
# Started export: image_tile_1191
# Started export: image_tile_1192
# Started export: image_tile_1193
# Started export: image_tile_1194
# Started export: image_tile_1195
# Started export: image_tile_1196
# Started export: image_tile_1197
# Started export: image_tile_1198
# Started export: image_tile_1199
# Started export: image_tile_1200
# Started export: image_tile_1201
# Started export: image_tile_1202
# Started export: image_tile_1203
# Started export: image_tile_1204
# Started export: image_tile_1205
# Started export: image_tile_1206
# Started export: image_tile_1207
# Started export: image_tile_1208
# Started export: image_tile_1209
# Started export: image_tile_1210
# Started export: image_tile_1211
# Started export: image_tile_1212
# Started export: image_tile_1213
# Started export: image_tile_1214
# Started export: image_tile_1215
# Started export: image_tile_1216
# Started export: image_tile_1217
# Started export: image_tile_1218
# Started export: image_tile_1219
# Started export: image_tile_1220
# Started export: image_tile_1221
# Started export: image_tile_1222
# Started export: image_tile_1223
# Started export: image_tile_1224
# Started export: image_tile_1225
# Started export: image_tile_1226
# Started export: image_tile_1227
# Started export: image_tile_1228
# Started export: image_tile_1229
# Started export: image_tile_1230
# Started export: image_tile_1231
# Started export: image_tile_1232
# Started export: image_tile_1233
# Started export: image_tile_1234
# Started export: image_tile_1235
# Started export: image_tile_1236
# Started export: image_tile_1237
# Started export: image_tile_1238
# Started export: image_tile_1239
# Started export: image_tile_1240
# Started export: image_tile_1241
# Started export: image_tile_1242
# Started export: image_tile_1243
# Started export: image_tile_1244
# Started export: image_tile_1245
# Started export: image_tile_1246
# Started export: image_tile_1247
# Started export: image_tile_1248
# Started export: image_tile_1249
# Started export: image_tile_1250
# Started export: image_tile_1251
# Started export: image_tile_1252
# Started export: image_tile_1253
# Started export: image_tile_1254
# Started export: image_tile_1255
# Started export: image_tile_1256
# Started export: image_tile_1257
# Started export: image_tile_1258
# Started export: image_tile_1259
# Started export: image_tile_1260
# Started export: image_tile_1261
# Started export: image_tile_1262
# Started export: image_tile_1263
# Started export: image_tile_1264
# Started export: image_tile_1265
# Started export: image_tile_1266
# Started export: image_tile_1267
# Started export: image_tile_1268
# Started export: image_tile_1269
# Started export: image_tile_1270
# Started export: image_tile_1271
# Started export: image_tile_1272
# Started export: image_tile_1273
# Started export: image_tile_1274
# Started export: image_tile_1275
# Started export: image_tile_1276
# Started export: image_tile_1277
# Started export: image_tile_1278
# Started export: image_tile_1279
# Started export: image_tile_1280
# Started export: image_tile_1281
# Started export: image_tile_1282
# Started export: image_tile_1283
# Started export: image_tile_1284
# Started export: image_tile_1285
# Started export: image_tile_1286
# Started export: image_tile_1287
# Started export: image_tile_1288
# Started export: image_tile_1289
# Started export: image_tile_1290
# Started export: image_tile_1291
# Started export: image_tile_1292
# Started export: image_tile_1293
# Started export: image_tile_1294
# Started export: image_tile_1295
# Started export: image_tile_1296
# Started export: image_tile_1297
# Started export: image_tile_1298
# Started export: image_tile_1299
# Started export: image_tile_1300
# Started export: image_tile_1301
# Started export: image_tile_1302
# Started export: image_tile_1303
# Started export: image_tile_1304
# Started export: image_tile_1305
# Started export: image_tile_1306
# Started export: image_tile_1307
# Started export: image_tile_1308
# Started export: image_tile_1309
# Started export: image_tile_1310
# Started export: image_tile_1311
# Started export: image_tile_1312
# Started export: image_tile_1313
# Started export: image_tile_1314
# Started export: image_tile_1315
# Started export: image_tile_1316
# Started export: image_tile_1317
# Started export: image_tile_1318
# Started export: image_tile_1319
# Started export: image_tile_1320
# Started export: image_tile_1321
# Started export: image_tile_1322
# Started export: image_tile_1323
# Started export: image_tile_1324
# Started export: image_tile_1325
# Started export: image_tile_1326
# Started export: image_tile_1327
# Started export: image_tile_1328
# Started export: image_tile_1329
# Started export: image_tile_1330
# Started export: image_tile_1331
# Started export: image_tile_1332
# Started export: image_tile_1333
# Started export: image_tile_1334
# Started export: image_tile_1335
# Started export: image_tile_1336
# Started export: image_tile_1337
# Started export: image_tile_1338
# Started export: image_tile_1339
# Started export: image_tile_1340
# Started export: image_tile_1341
# Started export: image_tile_1342
# Started export: image_tile_1343
# Started export: image_tile_1344
# Started export: image_tile_1345
# Started export: image_tile_1346
# Started export: image_tile_1347
# Started export: image_tile_1348
# Started export: image_tile_1349
# Started export: image_tile_1350
# Started export: image_tile_1351
# Started export: image_tile_1352
# Started export: image_tile_1353
# Started export: image_tile_1354
# Started export: image_tile_1355
# Started export: image_tile_1356
# Started export: image_tile_1357
# Started export: image_tile_1358
# Started export: image_tile_1359
# Started export: image_tile_1360
# Started export: image_tile_1361
# Started export: image_tile_1362
# Started export: image_tile_1363
# Started export: image_tile_1364
# Started export: image_tile_1365
# Started export: image_tile_1366
# Started export: image_tile_1367
# Started export: image_tile_1368
# Started export: image_tile_1369
# Started export: image_tile_1370
# Started export: image_tile_1371
# Started export: image_tile_1372
# Started export: image_tile_1373
# Started export: image_tile_1374
# Started export: image_tile_1375
# Started export: image_tile_1376
# Started export: image_tile_1377
# Started export: image_tile_1378
# Started export: image_tile_1379
# Started export: image_tile_1380
# Started export: image_tile_1381
# Started export: image_tile_1382
# Started export: image_tile_1383
# Started export: image_tile_1384
# Started export: image_tile_1385
# Started export: image_tile_1386
# Started export: image_tile_1387
# Started export: image_tile_1388
# Started export: image_tile_1389
# Started export: image_tile_1390
# Started export: image_tile_1391
# Started export: image_tile_1392
# Started export: image_tile_1393
# Started export: image_tile_1394
# Started export: image_tile_1395
# Started export: image_tile_1396
# Started export: image_tile_1397
# Started export: image_tile_1398
# Started export: image_tile_1399
# Started export: image_tile_1400
# Started export: image_tile_1401
# Started export: image_tile_1402
# Started export: image_tile_1403
# Started export: image_tile_1404
# Started export: image_tile_1405
# Started export: image_tile_1406
# Started export: image_tile_1407
# Started export: image_tile_1408
# Started export: image_tile_1409
# Started export: image_tile_1410
# Started export: image_tile_1411
# Started export: image_tile_1412
# Started export: image_tile_1413
# Started export: image_tile_1414
# Started export: image_tile_1415
# Started export: image_tile_1416
# Started export: image_tile_1417
# Started export: image_tile_1418
# Started export: image_tile_1419
# Started export: image_tile_1420
# Started export: image_tile_1421
# Started export: image_tile_1422
# Started export: image_tile_1423
# Started export: image_tile_1424
# Started export: image_tile_1425
# Started export: image_tile_1426
# Started export: image_tile_1427
# Started export: image_tile_1428
# Started export: image_tile_1429
# Started export: image_tile_1430
# Started export: image_tile_1431
# Started export: image_tile_1432
# Started export: image_tile_1433
# Started export: image_tile_1434
# Started export: image_tile_1435
# Started export: image_tile_1436
# Started export: image_tile_1437
# Started export: image_tile_1438
# Started export: image_tile_1439
# Started export: image_tile_1440
# Started export: image_tile_1441
# Started export: image_tile_1442
# Started export: image_tile_1443
# Started export: image_tile_1444
# Started export: image_tile_1445
# Started export: image_tile_1446
# Started export: image_tile_1447
# Started export: image_tile_1448
# Started export: image_tile_1449
# Started export: image_tile_1450
# Started export: image_tile_1451
# Started export: image_tile_1452
# Started export: image_tile_1453
# Started export: image_tile_1454
# Started export: image_tile_1455
# Started export: image_tile_1456
# Started export: image_tile_1457
# Started export: image_tile_1458
# Started export: image_tile_1459
# Started export: image_tile_1460
# Started export: image_tile_1461
# Started export: image_tile_1462
# Started export: image_tile_1463
# Started export: image_tile_1464
# Started export: image_tile_1465
# Started export: image_tile_1466
# Started export: image_tile_1467
# Started export: image_tile_1468
# Started export: image_tile_1469
# Started export: image_tile_1470
# Started export: image_tile_1471
# Started export: image_tile_1472
# Started export: image_tile_1473
# Started export: image_tile_1474
# Started export: image_tile_1475
# Started export: image_tile_1476
# Started export: image_tile_1477
# Started export: image_tile_1478
# Started export: image_tile_1479
# Started export: image_tile_1480
# Started export: image_tile_1481
# Started export: image_tile_1482
# Started export: image_tile_1483
# Started export: image_tile_1484
# Started export: image_tile_1485
# Started export: image_tile_1486
# Started export: image_tile_1487
# Started export: image_tile_1488
# Started export: image_tile_1489
# Started export: image_tile_1490
# Started export: image_tile_1491
# Started export: image_tile_1492
# Started export: image_tile_1493
# Started export: image_tile_1494
# Started export: image_tile_1495
# Started export: image_tile_1496
# Started export: image_tile_1497
# Started export: image_tile_1498
# Started export: image_tile_1499
# Started export: image_tile_1500
# Started export: image_tile_1501
# Started export: image_tile_1502
# Started export: image_tile_1503
# Started export: image_tile_1504
# Started export: image_tile_1505
# Started export: image_tile_1506
# Started export: image_tile_1507
# Started export: image_tile_1508
# Started export: image_tile_1509
# Started export: image_tile_1510
# Started export: image_tile_1511
# Started export: image_tile_1512
# Started export: image_tile_1513
# Started export: image_tile_1514
# Started export: image_tile_1515
# Started export: image_tile_1516
# Started export: image_tile_1517
# Started export: image_tile_1518
# Started export: image_tile_1519
# Started export: image_tile_1520
# Started export: image_tile_1521
# Started export: image_tile_1522
# Started export: image_tile_1523
# Started export: image_tile_1524
# Started export: image_tile_1525
# Started export: image_tile_1526
# Started export: image_tile_1527
# Started export: image_tile_1528
# Started export: image_tile_1529
# Started export: image_tile_1530
# Started export: image_tile_1531
# Started export: image_tile_1532
# Started export: image_tile_1533
# Started export: image_tile_1534
# Started export: image_tile_1535
# Started export: image_tile_1536
# Started export: image_tile_1537
# Started export: image_tile_1538
# Started export: image_tile_1539
# Started export: image_tile_1540
# Started export: image_tile_1541
# Started export: image_tile_1542
# Started export: image_tile_1543
# Started export: image_tile_1544
# Started export: image_tile_1545
# Started export: image_tile_1546
# Started export: image_tile_1547
# Started export: image_tile_1548
# Started export: image_tile_1549
# Started export: image_tile_1550
# Started export: image_tile_1551
# Started export: image_tile_1552
# Started export: image_tile_1553
# Started export: image_tile_1554
# Started export: image_tile_1555
# Started export: image_tile_1556
# Started export: image_tile_1557
# Started export: image_tile_1558
# Started export: image_tile_1559
# Started export: image_tile_1560
# Started export: image_tile_1561
# Started export: image_tile_1562
# Started export: image_tile_1563
# Started export: image_tile_1564
# Started export: image_tile_1565
# Started export: image_tile_1566
# Started export: image_tile_1567
# Started export: image_tile_1568
# Started export: image_tile_1569
# Started export: image_tile_1570
# Started export: image_tile_1571
# Started export: image_tile_1572
# Started export: image_tile_1573
# Started export: image_tile_1574
# Started export: image_tile_1575
# Started export: image_tile_1576
# Started export: image_tile_1577
# Started export: image_tile_1578
# Started export: image_tile_1579
# Started export: image_tile_1580
# Started export: image_tile_1581
# Started export: image_tile_1582
# Started export: image_tile_1583
# Started export: image_tile_1584
# Started export: image_tile_1585
# Started export: image_tile_1586
# Started export: image_tile_1587
# Started export: image_tile_1588
# Started export: image_tile_1589
# Started export: image_tile_1590
# Started export: image_tile_1591
# Started export: image_tile_1592
# Started export: image_tile_1593
# Started export: image_tile_1594
# Started export: image_tile_1595
# Started export: image_tile_1596
# Started export: image_tile_1597
# Started export: image_tile_1598
# Started export: image_tile_1599
# Started export: image_tile_1600
# Started export: image_tile_1601
# Started export: image_tile_1602
# Started export: image_tile_1603
# Started export: image_tile_1604
# Started export: image_tile_1605
# Started export: image_tile_1606
# Started export: image_tile_1607
# Started export: image_tile_1608
# Started export: image_tile_1609
# Started export: image_tile_1610
# Started export: image_tile_1611
# Started export: image_tile_1612
# Started export: image_tile_1613
# Started export: image_tile_1614
# Started export: image_tile_1615
# Started export: image_tile_1616
# Started export: image_tile_1617
# Started export: image_tile_1618
# Started export: image_tile_1619
# Started export: image_tile_1620
# Started export: image_tile_1621
# Started export: image_tile_1622
# Started export: image_tile_1623
# Started export: image_tile_1624
# Started export: image_tile_1625
# Started export: image_tile_1626
# Started export: image_tile_1627
# Started export: image_tile_1628
# Started export: image_tile_1629
# Started export: image_tile_1630
# Started export: image_tile_1631
# Started export: image_tile_1632
# Started export: image_tile_1633
# Started export: image_tile_1634
# Started export: image_tile_1635
# Started export: image_tile_1636
# Started export: image_tile_1637
# ...
# Started export: image_tile_3622
# Started export: image_tile_3623
# Started export: image_tile_3624
# Started export: image_tile_3625
# Started export: image_tile_3626
# Started export: image_tile_3627
# Started export: image_tile_3628
# Started export: image_tile_3629
# Started export: image_tile_3630
# Started export: image_tile_3631
# Started export: image_tile_3632
# Started export: image_tile_3633
# Started export: image_tile_3634
# Started export: image_tile_3635
# Started export: image_tile_3636
# Started export: image_tile_3637
# Started export: image_tile_3638
# Started export: image_tile_3639
# Started export: image_tile_3640
# Started export: image_tile_3641
# Started export: image_tile_3642
# Started export: image_tile_3643
# Started export: image_tile_3644
# Started export: image_tile_3645
# Started export: image_tile_3646
# Started export: image_tile_3647
# Started export: image_tile_3648
# Started export: image_tile_3649
# Started export: image_tile_3650
# Started export: image_tile_3651
# Started export: image_tile_3652
# Started export: image_tile_3653
# Started export: image_tile_3654
# Started export: image_tile_3655
# Started export: image_tile_3656
# Started export: image_tile_3657
# Started export: image_tile_3658
# Started export: image_tile_3659
# Started export: image_tile_3660
# Started export: image_tile_3661
# Started export: image_tile_3662
# Started export: image_tile_3663
# Started export: image_tile_3664
# Started export: image_tile_3665
# Started export: image_tile_3666
# Started export: image_tile_3667
# Started export: image_tile_3668
# Started export: image_tile_3669
# Started export: image_tile_3670
# Started export: image_tile_3671
# Started export: image_tile_3672
# Started export: image_tile_3673
# Started export: image_tile_3674
# Started export: image_tile_3675
# Started export: image_tile_3676
# Started export: image_tile_3677
# Started export: image_tile_3678
# Started export: image_tile_3679
# Started export: image_tile_3680
# Started export: image_tile_3681
# Started export: image_tile_3682
# Started export: image_tile_3683
# Started export: image_tile_3684
# Started export: image_tile_3685
# Started export: image_tile_3686
# Started export: image_tile_3687
# Started export: image_tile_3688
# Started export: image_tile_3689
# Started export: image_tile_3690
# Started export: image_tile_3691
# Started export: image_tile_3692
# Started export: image_tile_3693
# Started export: image_tile_3694
# Started export: image_tile_3695
# Started export: image_tile_3696
# Started export: image_tile_3697
# Started export: image_tile_3698
# Started export: image_tile_3699
# Started export: image_tile_3700
# Started export: image_tile_3701
# Started export: image_tile_3702
# Started export: image_tile_3703
# Started export: image_tile_3704
# Started export: image_tile_3705
# Started export: image_tile_3706
# Started export: image_tile_3707
# Started export: image_tile_3708
# Started export: image_tile_3709
# Started export: image_tile_3710
# Started export: image_tile_3711
# Started export: image_tile_3712
# Started export: image_tile_3713
# Started export: image_tile_3714
# Started export: image_tile_3715
# Started export: image_tile_3716
# Started export: image_tile_3717
# Started export: image_tile_3718
# Started export: image_tile_3719
# Started export: image_tile_3720
# Started export: image_tile_3721
# Started export: image_tile_3722
# Started export: image_tile_3723
# Started export: image_tile_3724
# Started export: image_tile_3725
# Started export: image_tile_3726
# Started export: image_tile_3727
# Started export: image_tile_3728
# Started export: image_tile_3729
# Started export: image_tile_3730
# Started export: image_tile_3731
# Started export: image_tile_3732
# Started export: image_tile_3733
# Started export: image_tile_3734
# Started export: image_tile_3735
# Started export: image_tile_3736
# Started export: image_tile_3737
# Started export: image_tile_3738
# Started export: image_tile_3739
# Started export: image_tile_3740
# Started export: image_tile_3741
# Started export: image_tile_3742
# Started export: image_tile_3743
# Started export: image_tile_3744
# Started export: image_tile_3745
# Started export: image_tile_3746
# Started export: image_tile_3747
# Started export: image_tile_3748
# Started export: image_tile_3749
# Started export: image_tile_3750
# Started export: image_tile_3751
# Started export: image_tile_3752
# Started export: image_tile_3753
# Started export: image_tile_3754
# Started export: image_tile_3755
# Started export: image_tile_3756
# Started export: image_tile_3757
# Started export: image_tile_3758
# Started export: image_tile_3759
# Started export: image_tile_3760
# Started export: image_tile_3761
# Started export: image_tile_3762
# Started export: image_tile_3763
# Started export: image_tile_3764
# Started export: image_tile_3765
# Started export: image_tile_3766
# Started export: image_tile_3767
# Started export: image_tile_3768
# Started export: image_tile_3769
# Started export: image_tile_3770
# Started export: image_tile_3771
# Started export: image_tile_3772
# Started export: image_tile_3773
# Started export: image_tile_3774
# Started export: image_tile_3775
# Started export: image_tile_3776
# Started export: image_tile_3777
# Started export: image_tile_3778
# Started export: image_tile_3779
# Started export: image_tile_3780
# Started export: image_tile_3781
# Started export: image_tile_3782
# Started export: image_tile_3783
# Started export: image_tile_3784
# Started export: image_tile_3785
# Started export: image_tile_3786
# Started export: image_tile_3787
# Started export: image_tile_3788
# Started export: image_tile_3789
# Started export: image_tile_3790
# Started export: image_tile_3791
# Started export: image_tile_3792
# Started export: image_tile_3793
# Started export: image_tile_3794
# Started export: image_tile_3795
# Started export: image_tile_3796
# Started export: image_tile_3797
# Started export: image_tile_3798
# Started export: image_tile_3799
# Started export: image_tile_3800
# Started export: image_tile_3801
# Started export: image_tile_3802
# Started export: image_tile_3803
# Started export: image_tile_3804
# Started export: image_tile_3805
# Started export: image_tile_3806
# Started export: image_tile_3807
# Started export: image_tile_3808
# Started export: image_tile_3809
# Started export: image_tile_3810
# Started export: image_tile_3811
# Started export: image_tile_3812
# Started export: image_tile_3813
# Started export: image_tile_3814
# Started export: image_tile_3815
# Started export: image_tile_3816
# Started export: image_tile_3817
# Started export: image_tile_3818
# Started export: image_tile_3819
# Started export: image_tile_3820
# Started export: image_tile_3821
# Started export: image_tile_3822
# Started export: image_tile_3823
# Started export: image_tile_3824
# Started export: image_tile_3825
# Started export: image_tile_3826
# Started export: image_tile_3827
# Started export: image_tile_3828
# Started export: image_tile_3829
# Started export: image_tile_3830
# Started export: image_tile_3831
# Started export: image_tile_3832
# Started export: image_tile_3833
# Started export: image_tile_3834
# Started export: image_tile_3835
# Started export: image_tile_3836
# Started export: image_tile_3837
# Started export: image_tile_3838
# Started export: image_tile_3839
# Started export: image_tile_3840
# Started export: image_tile_3841
# Started export: image_tile_3842
# Started export: image_tile_3843
# Started export: image_tile_3844
# Started export: image_tile_3845
# Started export: image_tile_3846
# Started export: image_tile_3847
# Started export: image_tile_3848
# Started export: image_tile_3849
# Started export: image_tile_3850
# Started export: image_tile_3851
# Started export: image_tile_3852
# Started export: image_tile_3853
# Started export: image_tile_3854
# Started export: image_tile_3855
# Started export: image_tile_3856
# Started export: image_tile_3857
# Started export: image_tile_3858
# Started export: image_tile_3859
# Started export: image_tile_3860
# Started export: image_tile_3861
# Started export: image_tile_3862
# Started export: image_tile_3863
# Started export: image_tile_3864
# Started export: image_tile_3865
# Started export: image_tile_3866
# Started export: image_tile_3867
# Started export: image_tile_3868
# Started export: image_tile_3869
# Started export: image_tile_3870
# Started export: image_tile_3871
# Started export: image_tile_3872
# Started export: image_tile_3873
# Started export: image_tile_3874
# Started export: image_tile_3875
# Started export: image_tile_3876
# Started export: image_tile_3877
# Started export: image_tile_3878
# Started export: image_tile_3879
# Started export: image_tile_3880
# Started export: image_tile_3881
# Started export: image_tile_3882
# Started export: image_tile_3883
# Started export: image_tile_3884
# Started export: image_tile_3885
# Started export: image_tile_3886
# Started export: image_tile_3887
# Started export: image_tile_3888
# Started export: image_tile_3889
# Started export: image_tile_3890
# Started export: image_tile_3891
# Started export: image_tile_3892
# Started export: image_tile_3893
# Started export: image_tile_3894
# Started export: image_tile_3895
# Started export: image_tile_3896
# Started export: image_tile_3897
# Started export: image_tile_3898
# Started export: image_tile_3899
# Started export: image_tile_3900
# Started export: image_tile_3901
# Started export: image_tile_3902
# Started export: image_tile_3903
# Started export: image_tile_3904
# Started export: image_tile_3905
# Started export: image_tile_3906
# Started export: image_tile_3907
# Started export: image_tile_3908
# Started export: image_tile_3909
# Started export: image_tile_3910
# Started export: image_tile_3911
# Started export: image_tile_3912
# Started export: image_tile_3913
# Started export: image_tile_3914
# Started export: image_tile_3915
# Started export: image_tile_3916
# Started export: image_tile_3917
# Started export: image_tile_3918
# Started export: image_tile_3919
# Started export: image_tile_3920
# Started export: image_tile_3921
# Started export: image_tile_3922
# Started export: image_tile_3923
# Started export: image_tile_3924
# Started export: image_tile_3925
# Started export: image_tile_3926
# Started export: image_tile_3927
# Started export: image_tile_3928
# Started export: image_tile_3929
# Started export: image_tile_3930
# Started export: image_tile_3931
# Started export: image_tile_3932
# Started export: image_tile_3933
# Started export: image_tile_3934
# Started export: image_tile_3935
# Started export: image_tile_3936
# Started export: image_tile_3937
# Started export: image_tile_3938
# Started export: image_tile_3939
# Started export: image_tile_3940
# Started export: image_tile_3941
# Started export: image_tile_3942
# Started export: image_tile_3943
# Started export: image_tile_3944
# Started export: image_tile_3945
# Started export: image_tile_3946
# Started export: image_tile_3947
# Started export: image_tile_3948
# Started export: image_tile_3949
# Started export: image_tile_3950
# Started export: image_tile_3951
# Started export: image_tile_3952
# Started export: image_tile_3953
# Started export: image_tile_3954
# Started export: image_tile_3955
# Started export: image_tile_3956
# Started export: image_tile_3957
# Started export: image_tile_3958
# Started export: image_tile_3959
# Started export: image_tile_3960
# Started export: image_tile_3961
# Started export: image_tile_3962
# Started export: image_tile_3963
# Started export: image_tile_3964
# Started export: image_tile_3965
# Started export: image_tile_3966
# Started export: image_tile_3967
# Started export: image_tile_3968
# Started export: image_tile_3969
# Started export: image_tile_3970
# Started export: image_tile_3971
# Started export: image_tile_3972
# Started export: image_tile_3973
# Started export: image_tile_3974
# Started export: image_tile_3975
# Started export: image_tile_3976
# Started export: image_tile_3977
# Started export: image_tile_3978
# Started export: image_tile_3979
# Started export: image_tile_3980
# Started export: image_tile_3981
# Started export: image_tile_3982
# Started export: image_tile_3983
# Started export: image_tile_3984
# Started export: image_tile_3985
# Started export: image_tile_3986
# Started export: image_tile_3987
# Started export: image_tile_3988
# Started export: image_tile_3989
# Started export: image_tile_3990
# Started export: image_tile_3991
# Started export: image_tile_3992
# Started export: image_tile_3993
# Started export: image_tile_3994
# Started export: image_tile_3995
# Started export: image_tile_3996
# Started export: image_tile_3997
# Started export: image_tile_3998
# Started export: image_tile_3999
# Started export: image_tile_4000
# Started export: image_tile_4001
# Started export: image_tile_4002
# Started export: image_tile_4003
# Started export: image_tile_4004
# Started export: image_tile_4005
# Started export: image_tile_4006
# Started export: image_tile_4007
# Started export: image_tile_4008
# Started export: image_tile_4009
# Started export: image_tile_4010
# Started export: image_tile_4011
# Started export: image_tile_4012
# Started export: image_tile_4013
# Started export: image_tile_4014
# Started export: image_tile_4015
# Started export: image_tile_4016
# Started export: image_tile_4017
# Started export: image_tile_4018
# Started export: image_tile_4019
# Started export: image_tile_4020
# Started export: image_tile_4021
# Started export: image_tile_4022
# Started export: image_tile_4023
# Started export: image_tile_4024
# Started export: image_tile_4025
# Started export: image_tile_4026
# Started export: image_tile_4027
# Started export: image_tile_4028
# Started export: image_tile_4029
# Started export: image_tile_4030
# Started export: image_tile_4031
# Started export: image_tile_4032
# Started export: image_tile_4033
# Started export: image_tile_4034
# Started export: image_tile_4035
# Started export: image_tile_4036
# Started export: image_tile_4037
# Started export: image_tile_4038
# Started export: image_tile_4039
# Started export: image_tile_4040
# Started export: image_tile_4041
# Started export: image_tile_4042
# Started export: image_tile_4043
# Started export: image_tile_4044
# Started export: image_tile_4045
# Started export: image_tile_4046
# Started export: image_tile_4047
# Started export: image_tile_4048
# Started export: image_tile_4049
# Started export: image_tile_4050
# Started export: image_tile_4051
# Started export: image_tile_4052
# Started export: image_tile_4053
# Started export: image_tile_4054
# Started export: image_tile_4055
# Started export: image_tile_4056
# Started export: image_tile_4057
# Started export: image_tile_4058
# Started export: image_tile_4059
# Started export: image_tile_4060
# Started export: image_tile_4061
# Started export: image_tile_4062
# Started export: image_tile_4063
# Started export: image_tile_4064
# Started export: image_tile_4065
# Started export: image_tile_4066
# Started export: image_tile_4067
# Started export: image_tile_4068
# Started export: image_tile_4069
# Started export: image_tile_4070
# Started export: image_tile_4071
# Started export: image_tile_4072
# Started export: image_tile_4073
# Started export: image_tile_4074
# Started export: image_tile_4075
# Started export: image_tile_4076
# Started export: image_tile_4077
# Started export: image_tile_4078
# Started export: image_tile_4079
# Started export: image_tile_4080
# Started export: image_tile_4081
# Started export: image_tile_4082
# Started export: image_tile_4083
# Started export: image_tile_4084
# Started export: image_tile_4085
# Started export: image_tile_4086
# Started export: image_tile_4087
# Started export: image_tile_4088
# Started export: image_tile_4089
# Started export: image_tile_4090
# Started export: image_tile_4091
# Started export: image_tile_4092
# Started export: image_tile_4093
# Started export: image_tile_4094
# Started export: image_tile_4095
# Started export: image_tile_4096
# Started export: image_tile_4097
# Started export: image_tile_4098
# Started export: image_tile_4099
# Started export: image_tile_4100
# Started export: image_tile_4101
# Started export: image_tile_4102
# Started export: image_tile_4103
# Started export: image_tile_4104
# Started export: image_tile_4105
# Started export: image_tile_4106
# Started export: image_tile_4107
# Started export: image_tile_4108
# Started export: image_tile_4109
# Started export: image_tile_4110
# Started export: image_tile_4111
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# I used slightly bigger geometries than needed - 1300 x 1300 meters rather than 1280 x 1280, so we have to crop each patch before inputing it into the model.

# %%
import tensorflow as tf
import numpy as np
import rasterio

def load_and_preprocess_tile(filepath, num_bands, target_size=128):
    with rasterio.open(filepath) as src:
        img = src.read()  # shape: (bands, H, W)

    img = np.transpose(img, (1, 2, 0))  # → (H, W, bands)
    img = img.astype(np.float32) / 10000.0

    # Convert to tensor
    img = tf.convert_to_tensor(img)

    # Center crop or pad to exactly 128×128
    img = tf.image.resize_with_crop_or_pad(img, target_size, target_size)

    return tf.expand_dims(img, axis=0)  # shape: (1, 128, 128, 10)

# %%
import os
from glob import glob
import rasterio
import numpy as np
from rasterio.transform import from_origin

def predict_tile_and_save(input_path, output_path, model, num_bands=10):
    # Load and preprocess
    tensor = load_and_preprocess_tile(input_path, num_bands=num_bands)
    prediction = model.predict(tensor)

    # Remove batch dim and squeeze final axis (e.g., shape [1, 128, 128, 1] → [128, 128])
    predicted_mask = np.squeeze(prediction, axis=(0, -1))

    # Save using original tile metadata
    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update({
            'count': 1,
            'dtype': 'float32',
            'compress': 'lzw'
        })
        with rasterio.open(output_path, 'w', **profile) as dst:
            dst.write(predicted_mask.astype(np.float32), 1)

# %% [markdown]
# Set input and output paths, and which model to use for the prediction.

# %%
input_dir = "/mnt/nfs/assets/dumpsites/to_predict/"
# output_dir = "/mnt/nfs/assets/dumpsites/predictions/kmeans_validated_label_v5/"
output_dir = "/mnt/nfs/assets/dumpsites/predictions/final_supervised_label_v5/"
os.makedirs(output_dir, exist_ok=True)

# model.load_weights('/mnt/nfs/assets/dumpsites/checkpoints/kmeans_validated_label_v5/kmeans_validated_label-cp-0050.weights.h5') #uncomment if you want to join
model.load_weights('/mnt/nfs/assets/dumpsites/checkpoints/final_supervised_label_v5/final_supervised_label-cp-0050.weights.h5') #uncomment if you want to join

tile_paths = sorted(glob(os.path.join(input_dir, "image_tile_*.tif")))

for tile_path in tile_paths:
    tile_name = os.path.basename(tile_path).replace("image_tile_", "pred_tile_")
    output_path = os.path.join(output_dir, tile_name)
    predict_tile_and_save(tile_path, output_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %% [markdown]
# Join every predicted patch into a single image.

# %%
from rasterio.merge import merge

predicted_tiles = sorted(glob(os.path.join(output_dir, "pred_tile_*.tif")))

# Read all tiles
srcs = [rasterio.open(path) for path in predicted_tiles]

# Merge with rasterio
merged_array, merged_transform = merge(srcs)

# Use metadata from the first tile
out_meta = srcs[0].meta.copy()
out_meta.update({
    "height": merged_array.shape[1],
    "width": merged_array.shape[2],
    "transform": merged_transform,
    "count": 1
})

# Save merged prediction
merged_output_path = os.path.join(output_dir, "merged_prediction_rf.tif")
with rasterio.open(merged_output_path, "w", **out_meta) as dest:
    dest.write(merged_array[0], 1)

# %% [markdown]
# The end! Go look at the final result!!
